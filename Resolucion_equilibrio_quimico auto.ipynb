# %% [markdown]
# ## Resolución de equilibrio químico del candy

# %% [markdown]
# aqui explico la reacción

# %% [markdown]
# #### Definición de reacciones de equilibrio y funciones

# %%
##-------------------------Ecuaciones de equilibrio------------------------------------

Eqn_1 = ['O','H','OH'] 
coef_1 = [-1,-1,1] 

Eqn_2 = ['O','O2']
coef_2 = [-2,1]

Eqn_3 = ['H','O2','OH','O']
coef_3 = [-1,-1,1,1]

Eqn_4 = ['H','OH','H2O']
coef_4 = [-1,-1,1]

Eqn_5 = ['H2','O','OH','H']
coef_5 = [-1,-1,1,1]

Eqn_6 = ['H2','OH','H2O','H']
coef_6 = [-1,-1,1,1]

Eqn_7 = ['H2O','O','OH']
coef_7 = [-1,-1,2]

##-----------------------------------Librerías--------------------------------------------------------

import matplotlib.pyplot as plt
import sympy as sp
import math
import json
from IPython.display import display, Markdown
import numpy as np
from scipy.optimize import minimize
import os
import pandas as pd

##///////////////////////////////---Cargado de datos y propiedades---///////////////////////////////////////////////

def cargar_datos(ruta):
    with open(ruta, 'r') as archivo:
        datos = json.load(archivo)
    return datos

def obtener_propiedades(datos, nombre_especie, propiedad):
    especie = datos.get(nombre_especie)
    if especie:
        return especie.get(propiedad)
    else:
        return None
   
##/////////////////////////////////---Entalpía, entropía y Cp---//////////////////////////////////////////////////////

def Cp_T(R,T,a_i,e_i):
    C_p = 0
    for index,i in enumerate(a_i):
        C_p += R*(a_i[index]*T**(e_i[index]))
    return C_p

def H_H0(R,T,a_i):
    T_0 = 298.15
    H = -a_i[0]/T + a_i[1]*math.log(T) + a_i[2]*T + a_i[3]*(T**2)/2 + a_i[4]*(T**3)/3 + a_i[5]*(T**4)/4 + a_i[6]*(T**5)/5
    H_0 = -a_i[0]/T_0 + a_i[1]*math.log(T_0) + a_i[2]*T_0 + a_i[3]*(T_0**2)/2 + a_i[4]*(T_0**3)/3 + a_i[5]*(T_0**4)/4 + a_i[6]*(T_0**5)/5
    return R * (H - H_0)/1000 # KJ/Kmol = J/mol

def S(R,T,a_i,b_i):
    S = -a_i[0]*(T**-2) - a_i[1]/T + a_i[2]*math.log(T) + a_i[3]*T + a_i[4]*(T**2)/2 + a_i[5]*(T**3)/3 + a_i[6]*(T**4)/4 + b_i[1]
    return R *(S) # J/mol K
 

##////////////////////////////////////---Kp_T----/////////////////////////////////////////////////////////

def Kp_T(Eqn_1,coef_1,T,ruta_archivos):
    ## Constantes universales
    R = 8.31415 # KJ/ Kmol K = J/mol K

    # Fuentes y datos predeterminados
    j = len(Eqn_1)
    tipo = 'Especies'
    datos = cargar_datos(ruta_archivos.get(tipo))

    ## Obtención de datos de intervalo de temperatura (en este caso 200-1000)
    M_i = [0]*j
    a_i = [0]*j
    b_i = [0]*j
    e_i = [0]*j
    T_int = [0]*j

    for index,i in enumerate(Eqn_1):
        M_i[index] = obtener_propiedades(datos, i, 'MolecWeight')[0]
        a_i[index] = obtener_propiedades(datos, i, 'Intervals')[0]['a']
        b_i[index] = obtener_propiedades(datos, i, 'Intervals')[0]['b']
        e_i[index] = obtener_propiedades(datos, i, 'Intervals')[0]['exp']
        T_int[index] = obtener_propiedades(datos, i, 'Intervals')[0]['T_int']

    ## Obtención entalpía de formación
    hf_i = [0]*j

    for index,i in enumerate(Eqn_1):
        hf_i[index] = (obtener_propiedades(datos, i, 'Enthalpy')[0])

    ## Obtención de la entalpía sensible molar (variación respecto del estandar) de cada componente
    hs_T_i = [0]*j

    for index,a in enumerate(a_i):
        hs_T_i[index] = H_H0(R,T,a)

    ## Obtención de la entalpía molar (variación respecto del estandar) de cada componente (formación + sensible)
    h_T_i = [x + y for x, y in zip(hf_i, hs_T_i)]
    #h_T_i = hs_T_i * 1000

    ## Obtención de la entropía molar para una T de cada componente
    s_T_i = [0]*j
    for index,a in enumerate(a_i):
        b = b_i[index]
        s_T_i[index] = S(R,T,a,b)

    ## Entalpía y entropía molar de la reacción
    h_T_r = 0
    s_T_r = 0

    for index,nu in enumerate(coef_1):
        h_T_r += nu*h_T_i[index]
        s_T_r += nu*s_T_i[index]

    g_T_r = h_T_r - T*s_T_r

    ## Contante de equilibrio para la temperatura T
    K_T = math.exp(-g_T_r/(R*T))

    return K_T 

##////////////////////////////////////---Newton-Raphson----/////////////////////////////////////////////////////////

def NewtonRaphson(hf_,R,coef_p,T_int_3, a_i_1, a_i_2, a_i_ng, x0, tolerance, Especies):

    indent_nogas = ['(L)','(s)','(a)','(b)'] # identificadores de no gas

    # Convertir x0 a flotante para cálculos numéricos
    x0 = float(x0)
    tramo = abs(2*tolerance)
    tabla = []

    T_0 = 298.15 # K

    cont = 0

    xi = sp.symbols('xi')  # Define xi como símbolo

    fx_ = 0
    dfx_ = 0

    while tramo >= tolerance:
        for index, i in enumerate(Especies):
            if any(ng in i for ng in indent_nogas): #si no es una especie gaseosa
                if  T_int_3[index][1] > x0:
                    #print(f'Temperatura fuera de rango (inferior al intervalo de la especie), elija otra fase de {i}')
                    #break 
                    a_i = a_i_ng[index]  # en parte es eroneo, debería estar lo comentado arriba
                    print(f'diferencia de rango (por debajo) de: {T_int_3[index][1]-x0}K') 
                elif x0 == T_int_3[index][1]:
                    a_i = a_i_ng[index]
                elif T_int_3[index][1] < x0 < T_int_3[index][2]:
                    a_i = a_i_ng[index]
                elif  T_int_3[index][2] < x0:
                    #print(f'Temperatura fuera de rango (inferior al intervalo de la especie), elija otra fase de {i}')
                    #break 
                    a_i = a_i_ng[index]  # en parte es eroneo, debería estar lo comentado arriba
                    print(f'diferencia de rango (por encima) de: {T_int_3[index][1]-x0}K') 
                else:
                    print(T_int_3[index][0],T_int_3[index][1],T_int_3[index][2])
                    print(x0)
                    print(f'Temperatura fuera de rango (valor no encontrado) elija otra fase de {i}')
                    break  
                
                H_0 = -a_i[0]/T_0 + a_i[1]*math.log(T_0) + a_i[2]*T_0 + a_i[3]*(T_0**2)/2 + a_i[4]*(T_0**3)/3 + a_i[5]*(T_0**4)/4 + a_i[6]*(T_0**5)/5
            # Actualización de fx_i y dfx_i usando xi 
                fx_i = -coef_p[index]* R *(-a_i[0]/xi + a_i[1]*sp.log(xi) + a_i[2]*xi + a_i[3]*(xi**2)/2 + a_i[4]*(xi**3)/3 + a_i[5]*(xi**4)/4 + a_i[6]*(xi**5)/5 - H_0)
                dfx_i = -coef_p[index]* R *(a_i[0]/(xi**2) + a_i[1]/xi + a_i[2] + a_i[3]*xi + a_i[4]*(xi**2) + a_i[5]*(xi**3) + a_i[6]*(xi**4))

                fx_ += fx_i
                dfx_ += dfx_i

            else: # si es especie gaseosa
                if  T_int_3[index][0] < x0 < T_int_3[index][1]:
                    a_i = a_i_1[index]
                elif x0 == T_int_3[index][1]:
                    a_i = a_i_1[index]
                elif T_int_3[index][1] < x0 < T_int_3[index][2]:
                    a_i = a_i_2[index]
                else:
                    print(f'Temperatura (T={x0}K) fuera de rango de {i}')
                    break  
                
                H_0 = -a_i[0]/T_0 + a_i[1]*math.log(T_0) + a_i[2]*T_0 + a_i[3]*(T_0**2)/2 + a_i[4]*(T_0**3)/3 + a_i[5]*(T_0**4)/4 + a_i[6]*(T_0**5)/5
            # Actualización de fx_i y dfx_i usando xi 
                fx_i = -coef_p[index]* R *(-a_i[0]/xi + a_i[1]*sp.log(xi) + a_i[2]*xi + a_i[3]*(xi**2)/2 + a_i[4]*(xi**3)/3 + a_i[5]*(xi**4)/4 + a_i[6]*(xi**5)/5 - H_0)
                dfx_i = -coef_p[index]* R *(a_i[0]/(xi**2) + a_i[1]/xi + a_i[2] + a_i[3]*xi + a_i[4]*(xi**2) + a_i[5]*(xi**3) + a_i[6]*(xi**4))

                fx_ += fx_i
                dfx_ += dfx_i

        fx_ = hf_ + fx_  # ahora las sumo, porque un poco más arriba porque fx_i va con un -, es decir, se resta

        # Incremento en el contador
        cont += 1

        # Definiendo funciones lambda para evaluación numérica
        fx = sp.lambdify(xi, fx_, 'numpy')
        dfx = sp.lambdify(xi, dfx_, 'numpy')

        # Resolvemos la iteración
        xnuevo = x0 - fx(x0)/dfx(x0)
        tramo = abs(xnuevo - x0)
        tabla.append([x0, xnuevo, tramo])
        x0_ = x0        # solo lo uso para la leyenda y la gráfica (nada más)
        x0 = xnuevo

        # Rango de valores para x y f(x)
        x_vals = np.linspace(1000, 3000, 100)
        y_vals = fx(x_vals)

        # Definimos el punto de iteración
        x_punto = x0_
        y_punto = fx(x0_)

        plt.figure(figsize=(10, 6))
        plt.scatter(x_punto, y_punto, color='red', label=f'$T_{cont+1}$ será {round(x0,ndigits=2)} K', zorder=3)
        plt.plot(x_vals, y_vals, label=f'$\Delta h_i(T_{cont} = {round(x0_,ndigits=2)}K)$')
        plt.title('Gráfico de $\\Delta\\bar{h}_i(T)$')
        plt.xlabel('$x$')
        plt.ylabel('$f(x)$')
        plt.legend()
        plt.grid(True)
        plt.show()

    return x0, tabla

##/////////////////////////////---TEMPERATURA DE COMBUSTIÓN ADIABÁTICA----/////////////////////////////////////////////

def T_adiab(Reactantes,Productos,coef_r,coef_p,ruta_archivos,R,T_in_NRaphson,tol_NRaphson):

    indent_nogas = ['(L)','(s)','(a)','(b)'] # identificadores de no gas
    j = len(Reactantes)  # Obtenemos la longitud de las listas de reactantes para inicializar otras listas
    k = len(Productos) # Obtenemos la longitud de las listas de productos para inicializar otras listas

    datos_r = cargar_datos(ruta_archivos.get('Reactantes'))
    datos_p = cargar_datos(ruta_archivos.get('Especies'))

    Eqn = Reactantes + Productos

    coef =  coef_r + [-x for x in coef_p] # positivos en los reactivos, negativos en los productos (xq pasamos restando los prod)

    hf_i_r = [0]*j
    hf_i_p = [0]*k

    for index,i in enumerate(Reactantes):
        hf_i_r[index] = obtener_propiedades(datos_r, i, 'Enthalpy')[0] # J/mol

    for index,i in enumerate(Productos):
        hf_i_p[index] = obtener_propiedades(datos_p, i, 'Enthalpy')[0] # J/mol

    #print(Productos)
    #print(hf_i_p)

    #hf_i = hf_i_r + hf_i_p

    hf_ = 0
    hf_r = 0#
    hf_p = 0#

    #for h,nu in zip(hf_i,coef): 
    #    hf_ += nu*h # J/mol 

    for h,nu in zip(hf_i_r,coef_r): 
        hf_r += nu*h # J/mol 

    for h,nu in zip(hf_i_p,coef_p): 
        hf_p += nu*h # J/mol 

    hf_ = hf_r - hf_p
    #print(hf_, hf_r, hf_p)

    ## Establecemos el polinomio de la entalpía para nuestras especies de los productos
    T_int = [0]*k # almacena los dos intervalos de temperatura con sus 2 temperaturas
    T_int_3 = [0]*k # almacena el límite superior e inferior total y la forontera entre los 2 intervalos

    a_i_ng = [0]*k # amacena las a_i del intervalo de temperaturas para especies NO gaseosas
    b_i_ng = [0]*k

    a_i_1 = [0]*k # amacena las a_i del intervalo de temperaturas 1 para especies gaseosas
    b_i_1 = [0]*k

    a_i_2 = [0]*k
    b_i_2 = [0]*k

    for index,i in enumerate(Productos):
        if any(ng in i for ng in indent_nogas):
            T_int[index] = [0,obtener_propiedades(datos_p, i, 'Intervals')[0]['T_int'][0]]+obtener_propiedades(datos_p, i, 'Intervals')[0]['T_int']
        else:
            T_int[index] = obtener_propiedades(datos_p, i, 'Intervals')[0]['T_int']+obtener_propiedades(datos_p, i, 'Intervals')[1]['T_int']
        
        T_int_3[index] = [T_int[index][0],(T_int[index][1]+T_int[index][2])/2,T_int[index][3]]

    for index,i in enumerate(Productos):
        if any(ng in i for ng in indent_nogas): #si no es una especie gaseosa
            a_i_ng[index] = obtener_propiedades(datos_p, i, 'Intervals')[0]['a']
            b_i_ng[index] = obtener_propiedades(datos_p, i, 'Intervals')[0]['b']
            
        else: # si es especie gaseosa
            a_i_1[index] = obtener_propiedades(datos_p, i, 'Intervals')[0]['a']
            b_i_1[index] = obtener_propiedades(datos_p, i, 'Intervals')[0]['b']

            a_i_2[index] = obtener_propiedades(datos_p, i, 'Intervals')[1]['a']
            b_i_2[index] = obtener_propiedades(datos_p, i, 'Intervals')[1]['b']

    def NewtonRaphson_Tad(T_int_3, a_i_1, a_i_2, a_i_ng, x0, tolerance, Especies):
    # Convertir x0 a flotante para cálculos numéricos

        x0 = float(x0)
        tramo = abs(2*tolerance)
        tabla = []

        T_0 = 298.15 # K

        cont = 0

        xi = sp.symbols('xi')  # Define xi como símbolo

        fx_ = 0
        dfx_ = 0

        while tramo >= tolerance:
            for index, i in enumerate(Especies):
                if any(ng in i for ng in indent_nogas): #si no es una especie gaseosa
                    if  T_int_3[index][1] > x0:
                        #print(f'Temperatura fuera de rango (inferior al intervalo de la especie), elija otra fase de {i}')
                        #break 
                        a_i = a_i_ng[index]  # en parte es eroneo, debería estar lo comentado arriba
                        print(f'diferencia de rango (por debajo) de: {T_int_3[index][1]-x0}K') 
                    elif x0 == T_int_3[index][1]:
                        a_i = a_i_ng[index]
                    elif T_int_3[index][1] < x0 < T_int_3[index][2]:
                        a_i = a_i_ng[index]
                    elif  T_int_3[index][2] < x0:
                        #print(f'Temperatura fuera de rango (inferior al intervalo de la especie), elija otra fase de {i}')
                        #break 
                        a_i = a_i_ng[index]  # en parte es eroneo, debería estar lo comentado arriba
                        print(f'diferencia de rango (por encima) de: {T_int_3[index][1]-x0}K') 
                    else:
                        print(T_int_3[index][0],T_int_3[index][1],T_int_3[index][2])
                        print(x0)
                        print(f'Temperatura fuera de rango (valor no encontrado) elija otra fase de {i}')
                        break  
                    
                    H_0 = -a_i[0]/T_0 + a_i[1]*math.log(T_0) + a_i[2]*T_0 + a_i[3]*(T_0**2)/2 + a_i[4]*(T_0**3)/3 + a_i[5]*(T_0**4)/4 + a_i[6]*(T_0**5)/5
                # Actualización de fx_i y dfx_i usando xi 
                    fx_i = -coef_p[index]* R *(-a_i[0]/xi + a_i[1]*sp.log(xi) + a_i[2]*xi + a_i[3]*(xi**2)/2 + a_i[4]*(xi**3)/3 + a_i[5]*(xi**4)/4 + a_i[6]*(xi**5)/5 - H_0)
                    dfx_i = -coef_p[index]* R *(a_i[0]/(xi**2) + a_i[1]/xi + a_i[2] + a_i[3]*xi + a_i[4]*(xi**2) + a_i[5]*(xi**3) + a_i[6]*(xi**4))

                    fx_ += fx_i
                    dfx_ += dfx_i

                else: # si es especie gaseosa
                    if  T_int_3[index][0] < x0 < T_int_3[index][1]:
                        a_i = a_i_1[index]
                    elif x0 == T_int_3[index][1]:
                        a_i = a_i_1[index]
                    elif T_int_3[index][1] < x0 < T_int_3[index][2]:
                        a_i = a_i_2[index]
                    else:
                        print(f'Temperatura (T={x0}K) fuera de rango de {i}')
                        break  
                    
                    H_0 = -a_i[0]/T_0 + a_i[1]*math.log(T_0) + a_i[2]*T_0 + a_i[3]*(T_0**2)/2 + a_i[4]*(T_0**3)/3 + a_i[5]*(T_0**4)/4 + a_i[6]*(T_0**5)/5
                # Actualización de fx_i y dfx_i usando xi 
                    fx_i = -coef_p[index]* R *(-a_i[0]/xi + a_i[1]*sp.log(xi) + a_i[2]*xi + a_i[3]*(xi**2)/2 + a_i[4]*(xi**3)/3 + a_i[5]*(xi**4)/4 + a_i[6]*(xi**5)/5 - H_0)
                    dfx_i = -coef_p[index]* R *(a_i[0]/(xi**2) + a_i[1]/xi + a_i[2] + a_i[3]*xi + a_i[4]*(xi**2) + a_i[5]*(xi**3) + a_i[6]*(xi**4))

                    fx_ += fx_i
                    dfx_ += dfx_i

            fx_ = hf_ + fx_  # ahora las sumo, porque un poco más arriba porque fx_i va con un -, es decir, se resta

            # Incremento en el contador
            cont += 1

            # Definiendo funciones lambda para evaluación numérica
            fx = sp.lambdify(xi, fx_, 'numpy')
            dfx = sp.lambdify(xi, dfx_, 'numpy')

            # Resolvemos la iteración
            xnuevo = x0 - fx(x0)/dfx(x0)
            tramo = abs(xnuevo - x0)
            tabla.append([x0, xnuevo, tramo])
            x0_ = x0        # solo lo uso para la leyenda y la gráfica (nada más)
            x0 = xnuevo

            # Rango de valores para x y f(x)
            x_vals = np.linspace(1000, 3000, 100)
            y_vals = fx(x_vals)

            # Definimos el punto de iteración
            x_punto = x0_
            y_punto = fx(x0_)


            #plt.figure(figsize=(10, 6))
            #plt.scatter(x_punto, y_punto, color='red', label=f'$T_{cont+1}$ será {round(x0,ndigits=2)} K', zorder=3)
            #plt.plot(x_vals, y_vals, label=f'$\Delta h_i(T_{cont} = {round(x0_,ndigits=2)}K)$')
            #plt.title('Gráfico de $\\Delta\\bar{h}_i(T)$')
            #plt.xlabel('$x$')
            #plt.ylabel('$f(x)$')
            #plt.legend()
            #plt.grid(True)
            #plt.show()


        return x0 #, tabla   # Temperatura final , Tabla de valores de convergencia
    
    x0 = T_in_NRaphson
    tolerance = tol_NRaphson

    return NewtonRaphson_Tad(T_int_3, a_i_1, a_i_2, a_i_ng, x0, tolerance, Productos)


##/////////////////////////////////---Extracción de datos de combustión---//////////////////////////////////////////////////////


def Datos_ProductosComb(ruta_archivos,Productos,Tc,R):
    '''
    Extrae Mm, e_i, a_i y b_i de cada uno de los componentes de los productos
    para después poder realizar operaciones con ellos de manera sencilla
    '''

    indent_nogas = ['(L)','(s)','(a)','(b)'] # identificadores de no gas
    
    tipo = 'Especies'
    
    datos_p = cargar_datos(ruta_archivos.get(tipo))
    numero_prod=len(Productos)

    Mm = [0]*numero_prod
    T_int = [0]*numero_prod
    T_int_3 = [0]*numero_prod
    e_i = [0]*numero_prod
    a_i = [0]*numero_prod
    b_i = [0]*numero_prod
    a_i_ng = [0]*numero_prod
    b_i_ng = [0]*numero_prod
    a_i_1 = [0]*numero_prod
    a_i_2 = [0]*numero_prod
    b_i_1 = [0]*numero_prod
    b_i_2 = [0]*numero_prod
    Cp_i = [0]*numero_prod
    Hs_i = [0]*numero_prod
    S_i = [0]*numero_prod

    ## Obtenemos sus masas moleculares y sus intervalos
    for index,i in enumerate(Productos):
        Mm[index] = obtener_propiedades(datos_p, i, 'MolecWeight')[0]
        e_i[index] = obtener_propiedades(datos_p, i, 'Intervals')[0]['exp']
        if any(ng in i for ng in indent_nogas):
            T_int[index] = [0,obtener_propiedades(datos_p, i, 'Intervals')[0]['T_int'][0]]+obtener_propiedades(datos_p, i, 'Intervals')[0]['T_int']
            a_i_ng[index] = obtener_propiedades(datos_p, i, 'Intervals')[0]['a']
            b_i_ng[index] = obtener_propiedades(datos_p, i, 'Intervals')[0]['b']        
        else:
            T_int[index] = obtener_propiedades(datos_p, i, 'Intervals')[0]['T_int']+obtener_propiedades(datos_p, i, 'Intervals')[1]['T_int']
            a_i_1[index] = obtener_propiedades(datos_p, i, 'Intervals')[0]['a']
            b_i_1[index] = obtener_propiedades(datos_p, i, 'Intervals')[0]['b']

            a_i_2[index] = obtener_propiedades(datos_p, i, 'Intervals')[1]['a']
            b_i_2[index] = obtener_propiedades(datos_p, i, 'Intervals')[1]['b']

        T_int_3[index] = [T_int[index][0],(T_int[index][1]+T_int[index][2])/2,T_int[index][3]]

    ## Asignamos los intervalos en función de la temperatura de combustión obtenida
    for index, i in enumerate(Productos):
        if any(ng in i for ng in indent_nogas): #si no es una especie gaseosa
            if  T_int_3[index][1] > Tc:
                print(f'Temperatura fuera de rango (inferior al intervalo de la especie), elija otra fase de {i}')
                break 
                #a_i = a_i_ng[index]  # en parte es eroneo, debería estar lo comentado arriba
                #b_i = b_i_ng[index]
                #print(f'diferencia de rango (por debajo) de: {T_int_3[index][1]-Tc}K') 
            elif Tc == T_int_3[index][1]:
                a_i[index] = a_i_ng[index]
                b_i[index] = b_i_ng[index]
            elif T_int_3[index][1] < Tc < T_int_3[index][2]:
                a_i[index] = a_i_ng[index]
                b_i[index] = b_i_ng[index]
            elif  T_int_3[index][2] < Tc:
                print(f'Temperatura fuera de rango (inferior al intervalo de la especie), elija otra fase de {i}')
                break 
                #a_i = a_i_ng[index]  # en parte es eroneo, debería estar lo comentado arriba
                #b_i = b_i_ng[index]
                #print(f'diferencia de rango (por encima) de: {T_int_3[index][1]-Tc}K') 
            else:
                print(T_int_3[index][0],T_int_3[index][1],T_int_3[index][2])
                print(Tc)
                print(f'Temperatura fuera de rango (valor no encontrado) elija otra fase de {i}')
                break  

        else: # si es especie gaseosa
            if  T_int_3[index][0] < Tc < T_int_3[index][1]:
                a_i[index] = a_i_1[index]
                b_i[index] = b_i_1[index]
            elif Tc == T_int_3[index][1]:
                a_i[index] = a_i_1[index]
                b_i[index] = b_i_1[index]
            elif T_int_3[index][1] < Tc < T_int_3[index][2]:
                a_i[index] = a_i_2[index]
                b_i[index] = b_i_2[index]
            else:
                print(f'Temperatura (T={Tc}K) fuera de rango de {i}')
                break 

    ## Calculamos Cp, Hs y S para la temperatura dada
        Cp_i[index] = Cp_T(R,Tc,a_i[index],e_i[index])
        Hs_i[index] = H_H0(R,Tc,a_i[index])
        S_i[index] = S(R,Tc,a_i[index],b_i[index])

    return Mm,e_i,a_i,b_i,Cp_i,Hs_i,S_i
# Out:
# <>:227: SyntaxWarning: invalid escape sequence '\D'
# <>:227: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\german.perez\AppData\Local\Temp\ipykernel_56564\2200325066.py:227: SyntaxWarning: invalid escape sequence '\D'
#   plt.plot(x_vals, y_vals, label=f'$\Delta h_i(T_{cont} = {round(x0_,ndigits=2)}K)$')

# %%
#/////////////////////////--RUTA DE ARCHIVOS DE BASES DE DATOS--//////////////////////////////////////////
ruta_archivos = {
    'Reactantes' : 'C:/Users/german.perez/OneDrive - Destinus NL BV/Escritorio/Personal/TFG/code/Bases de datos/Reactants.json',
    'Especies' : 'C:/Users/german.perez/OneDrive - Destinus NL BV/Escritorio/Personal/TFG/code/Bases de datos/Species.json',
    'Propulsantes' : 'C:/Users/german.perez/OneDrive - Destinus NL BV/Escritorio/Personal/TFG/code/Bases de datos/Propellants.json'
}

#/////////////////////////--RUTA DE ARCHIVOS DE PRESION Y TIEMPO--//////////////////////////////////////////

# Definir la ruta del archivo
file_path = r"C:/Users/german.perez/OneDrive - Destinus NL BV/Escritorio/Personal/TFG/Fotos/6 - Resultados/Resultados Equilibrio Químico/presion y tiempo.txt"

# Leer los datos asumiendo separador de espacios y punto decimal
df = pd.read_csv(file_path, sep='\s+', decimal='.', header=None)

# Definir los nombres de las columnas
df.columns = ['Tiempo', 'Presión']

#////////////////////////--ARREGLOS PARA EL GUARDADO--//////////////////////////////////////////////////////////////

# Definir el directorio donde se guardará el archivo
output_dir = "C:/Users/german.perez/OneDrive - Destinus NL BV/Escritorio/Personal/TFG/Fotos/6 - Resultados" 

# Crear el directorio si no existe
os.makedirs(output_dir, exist_ok=True)

# Ruta del archivo de salida con el valor del tiempo en el nombre
output_file = os.path.join(output_dir, f"resultados_equilibrio.txt")

output_text="""Tiempo Presión Temperatura Cp Mm Rg Gamma Vsound N_KOH N_K2CO3 N_K2O N_CO N_CO2 N_H2O N_H2 N_H N_OH N_O N_O2 N_N2"""

# Guardar en un archivo de texto
with open(output_file, "w") as f:
    f.write(output_text)

## Constantes universales
R = 8.31415 # KJ/ Kmol K = J/mol K

## Temperaturas y presiones estandar
T_0 = 298.15 # K
p0 = 1.0  # Presión estándar

## Definición de mezcla de reactivos
N_KNO3 = 1
N_C6H14O6 = 0.2988

## Nombre de las especies de la reacción
Reactantes = ['KNO3(s)','Sorbitol']
coef_r = [N_KNO3,N_C6H14O6]
Productos = ['KOH(L)','K2CO3(L)','K2O','CO','CO2','H2O','H2','H','OH','O','O2']						

coef_p = [0.000360065792818802, 0.493640832027809, 0.00272566861913182,
                0.87866000126, 0.40143172266, 1.63439159539, 0.45389515045,
                0.00000846023, 0.00012044938, 0.00000013817, 0.0000000001]
N_N2 = [0.5] # fracción molar de N2
N_m = [4.3619322173912005] # suma de los coef, estequeométricos


#////////////////////////--VALORES INICIALES--//////////////////////////////////////////////////////////////

initial_guess = coef_p+N_m ## Composiciones de N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_m
T_inicial_iteracion = 1559 # K : Temperatura única en la que se analiza Kp
T_in_NRaphson = 1550 # K : Temperatura única en la que se analiza en el NRaphson
x_tot_0 = 0.5 ## Valor inicial de la suma de fracciones molares

#////////////////////////--TOLERANCIAS DE CONVERGENCIA--//////////////////////////////////////////////////////////

tol_x = 0.01 # tolerancia de convergencia para la fracción molar
tol_Tad = 0.001 # tolerancia de convergencia para la T_adiabática
tol_NRaphson = 10 # Tolerancia de convergencia del NRaphson

#////////////////////////--ARREGLOS PARA LA TEMP. ADIAB.--//////////////////////////////////////////////////////////

indent_nogas = ['(L)','(s)','(a)','(b)'] # identificadores de no gas

################################################################################################################
################################################################################################################
################################################################################################################

#////////////////////////--INICIO DE LAS ITERACIONES.--/////////////////////////////////////////////////////////////

# Iterar sobre cada fila y mostrar los valores de Tiempo y Presión
for index, row in df.iterrows():

    #///////////////--DEFINICIÓN DE CONDICIONES Y REACCIÓN QUÍMICA--//////////////////////////////////////////

    ## Paso de tiempo
    tiempo = row['Tiempo']# En segundos

    ## Presión de cámara
    p = row['Presión'] # Presión de cámara

    #///////////////--INICIO DEL CÁLCULO--//////////////////////////////////////////

    T = T_inicial_iteracion # Antes de entrar al bucle inicializo la temperatura
    T_nueva = T_inicial_iteracion + 100
    contador_iter = 0

    while abs(T-T_nueva) >= tol_Tad:

        contador_iter += 1
        print(f'En la iteración {contador_iter} obtenemos:')

        T = T_nueva # temperatura obtenida en el anterior bucle y la que se usa para la concentración de equilibrio

        ## Constantes de equilibrio
        K_p_H_O_OH = Kp_T(Eqn_1,coef_1,T,ruta_archivos)
        K_p_O_O2 = Kp_T(Eqn_2,coef_2,T,ruta_archivos)
        K_p_H_O2_OH_O = Kp_T(Eqn_3,coef_3,T,ruta_archivos)
        K_p_H_OH_H2O = Kp_T(Eqn_4,coef_4,T,ruta_archivos)
        K_p_H2_O_OH_H = Kp_T(Eqn_5,coef_5,T,ruta_archivos)
        K_p_H2_OH_H2O_H = Kp_T(Eqn_6,coef_6,T,ruta_archivos)
        K_p_H2O_O_OH = Kp_T(Eqn_7,coef_7,T,ruta_archivos)


        # Define the function to compute the residuals as the sum of squares of each equation
        def objective(vars):
            N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_m = vars
            
            eq1 = 2 * N_K2CO3 + 2 * N_K2O + N_KOH - 1*N_KNO3
            eq2 = N_CO + N_CO2 + N_K2CO3 - 6*N_C6H14O6
            eq3 = N_H + 2 * N_H2 + 2 * N_H2O + N_KOH + N_OH - 14*N_C6H14O6
            eq4 = N_CO + 2 * N_CO2 + N_H2O + 3 * N_K2CO3 + N_K2O + N_KOH + N_O + 2 * N_O2 + N_OH - 3*N_KNO3 - 6*N_C6H14O6

            eq5 = N_CO + N_CO2 + N_H + N_H2 + N_H2O + N_K2CO3 + N_K2O + N_KOH + N_O + N_O2 + N_OH - N_m + 0.5

            eq6 = (p0/p) * N_OH * N_m  - K_p_H_O_OH* (N_H * N_O)
            eq7 = (p0/p) * N_O2 * N_m  - K_p_O_O2*N_O**2
            eq8 = N_O * N_OH  - K_p_H_O2_OH_O*(N_H * N_O2)
            eq9 = (p0/p) * N_H2O * N_m - K_p_H_OH_H2O*(N_H * N_OH)
            eq10 = N_H * N_OH  - K_p_H2_O_OH_H*(N_H2 * N_O)
            eq11 = N_H * N_H2O - K_p_H2_OH_H2O_H*(N_H2 * N_OH)
            eq12 = N_OH**2 - K_p_H2O_O_OH*(N_H2O * N_O)

            # Return the sum of squares of the residuals
            return (eq1**2 + eq2**2 + eq3**2 + eq4**2 + eq5**2 +
                    eq6**2 + eq7**2 + eq8**2 + eq9**2 + eq10**2 + eq11**2 + eq12**2)

        x_tot = x_tot_0

        while abs(x_tot-1) >= tol_x:
            #print(x_tot-1,tolerancia)

            # Define bounds for each variable to be greater than zero
            bounds = [(1e-10, None)] * 12  # Use a small number close to zero to avoid division by zero in equations

            # Use 'L-BFGS-B' because it supports bounds
            solution_1 = minimize(objective, initial_guess, bounds=bounds, method='L-BFGS-B')

            #print("Solución:")
            #print(solution_1.x)  # Shows the optimized values of the variables

            initial_guess = solution_1.x.tolist()

            x_i = [0]*len(solution_1.x)
            x_tot = 0.5/solution_1.x[11] # aqui tengo en cuenta ya el nitrógeno
            for index,i in enumerate(solution_1.x):
                x_i[index] = solution_1.x[index]/solution_1.x[11]
                x_tot += x_i[index]
                if index == 10:
                    break

            print(f'Suma de fracciones molares: {x_tot}')

        
        print(f'Temperatura de combustión inicial: {T}K')
        print("Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2")
        print(solution_1.x.tolist()[:11]+N_N2)  # Shows the optimized values of the variables
        print(f'Suma de coeficientes (N_m): {solution_1.x.tolist()[11]}')


        Productos_tot = Productos + ['N2']

        coef_p_tot = solution_1.x.tolist()[:11]+N_N2

        ## Ahora calculamos la nueva temperatura de combustión adiabática para la siguiente iteración
        T_nueva = T_adiab(Reactantes,Productos_tot,coef_r,coef_p_tot,ruta_archivos,R,T,tol_NRaphson)

    Coef = solution_1.x.tolist()[:11]+N_N2
    N_m=solution_1.x.tolist()[11]

    Mm_i = Datos_ProductosComb(ruta_archivos,Productos,T_nueva,R)[0]  # Mm,e_i,a_i,b_i,Cp_i,Hs_i,S_i
    Cp_i = Datos_ProductosComb(ruta_archivos,Productos,T_nueva,R)[4]  # Mm,e_i,a_i,b_i,Cp_i,Hs_i,S_i

    ## Cálculo de Cp_mezcla, Mm_mezcla, Gamma_mezcla, Vsonido_mezcla

    indent_nogas = ['(L)','(s)','(a)','(b)'] # identificadores de no gas
    C_ng, Cp_gas,Cp_mix,Mm_ng,Mm_gas,Mm_mix,N_ng,N_gas = 0,0,0,0,0,0,0,0

    for index, i in enumerate(Productos):
        if any(ng in i for ng in indent_nogas): #si no es una especie gaseosa
            C_ng += (Coef[index])*Cp_i[index]
            Mm_ng += (Coef[index])*Mm_i[index]
            N_ng += Coef[index]
        else:
            Cp_gas += (Coef[index])*Cp_i[index]
            Mm_gas += (Coef[index])*Mm_i[index]
            N_gas += Coef[index]

        Cp_mix += C_ng + Cp_gas
        Mm_mix += Mm_ng + Mm_gas

    C_ng = C_ng/N_ng
    Cp_gas = Cp_gas/N_m #Cp_gas/N_gas
    Cp_mix = Cp_mix/N_m
    Mm_ng = Mm_ng/N_ng
    Mm_gas = Mm_gas/N_gas
    Mm_mix = Mm_mix/N_m

    Gamma_gas = Cp_gas / (Cp_gas-R)
    Gamma_mix = Cp_mix / (Cp_mix-R)

    Vsound_gas = np.sqrt(Gamma_gas*(R/(Mm_gas/1000))*T_nueva)
    Vsound_mix = np.sqrt(Gamma_mix*(R/(Mm_mix/1000))*T_nueva)

    # Datos a escribir en el archivo (El 11 es el numero de moles ojo)
    output_text = f"""
 {tiempo} {round(p, ndigits=2)} {round(T_nueva, ndigits=2)} {round(Cp_gas, ndigits=4)} {round(Mm_gas/1000, ndigits=7)} {round(R/(Mm_gas/1000), ndigits=4)} {round(Gamma_gas, ndigits=4)} {round(Vsound_gas, ndigits=2)} {solution_1.x.tolist()[0]} {solution_1.x.tolist()[1]} {solution_1.x.tolist()[2]} {solution_1.x.tolist()[3]} {solution_1.x.tolist()[4]} {solution_1.x.tolist()[5]} {solution_1.x.tolist()[6]} {solution_1.x.tolist()[7]} {solution_1.x.tolist()[8]} {solution_1.x.tolist()[9]} {solution_1.x.tolist()[10]} {N_N2[0]}"""
    
    print(f"Archivo generado exitosamente en: {output_text}")
    
    # Guardar en un archivo de texto
    with open(output_file, "a") as f:
        f.write(output_text)

# Mostrar la ruta del archivo generado
print(f"Archivo generado exitosamente en: {output_file}")
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\german.perez\AppData\Local\Temp\ipykernel_56564\3430453261.py:14: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(file_path, sep='\s+', decimal='.', header=None)
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.0007756578582525
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003600657940146247, 0.4936408320317225, 0.002725668620744906, 0.8786600012642589, 0.40143172266060767, 1.6343915953015455, 0.45389515045442885, 8.072034602871264e-05, 0.00012968930053737897, 1.3822885263916453e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3619322171013835
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.0005345370203227
# Temperatura de combustión inicial: 1559.514975166331K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003600525048516974, 0.49364079102869973, 0.0027256516855024555, 0.878659957546894, 0.40143171558303997, 1.6329120808934636, 0.45389510393865157, 1.4736548304584455e-05, 6.893521393749401e-05, 1.3280542798635456e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361377839933713
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.00046189255981
# Temperatura de combustión inicial: 1558.5583103670813K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003557276450444657, 0.4936334851235282, 0.0027225120056609984, 0.878653913600127, 0.4014288548118312, 1.6324588293673465, 0.4538864113835555, 1.4357971260313207e-05, 6.908662358681066e-05, 1.300899046101371e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361208898779722
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.0008355002286253
# Temperatura de combustión inicial: 1558.2080287395006K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004196596938750516, 0.49373346640716975, 0.0027659090232345436, 0.8787314641785542, 0.4014722572323276, 1.634320667112818, 0.4540050187351537, 1.429706900223128e-05, 6.886343035627432e-05, 1.296016507163221e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361887374685354
# En la iteración 5 obtenemos:
# Suma de fracciones molares: 1.0008356742863136
# Temperatura de combustión inicial: 1559.9759886984618K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041965969401099067, 0.49373346640772436, 0.0027659090234253224, 0.8787314641793276, 0.40147225723231883, 1.634320667108554, 0.45400501873601684, 1.4911150880989092e-05, 6.900857928979983e-05, 1.2959053766385876e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361887374683268
# Archivo generado exitosamente en:
#  0.0 1.0 1559.98 33.9148 0.0216237 384.4928 1.3248 891.4 0.00041965969401099067 0.49373346640772436 0.0027659090234253224 0.8787314641793276 0.40147225723231883 1.634320667108554 0.45400501873601684 1.4911150880989092e-05 6.900857928979983e-05 1.2959053766385876e-07 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.0008366092194183
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041965970425294395, 0.49373346644973176, 0.0027659090378556865, 0.8787314642379359, 0.40147225723161295, 1.6343206670761905, 0.4540050188013797, 1.8236845590630065e-05, 6.976088070063202e-05, 1.2952364191731877e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361887374697156
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.0009495904949666
# Temperatura de combustión inicial: 1559.9719816172799K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004196069019611187, 0.49373809733919083, 0.0027670579910290473, 0.8787419909730514, 0.401469029590379, 1.635119779244667, 0.4540135320297635, 1.876901996947211e-06, 6.666178020119075e-05, 1.2672862787250023e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362195460234643
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.0009516471742084
# Temperatura de combustión inicial: 1560.5594086747935K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041911561962450157, 0.4937437326706684, 0.002768249536414661, 0.8787565723892675, 0.40146375954139135, 1.6351113351623279, 0.4540246303196184, 1.8904518931900924e-06, 6.716056697377595e-05, 1.229367307596224e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362205288958355
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.0009527968960854
# Temperatura de combustión inicial: 1560.567145157626K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004187979232268435, 0.493747264129453, 0.002768958135299766, 0.8787659640730746, 0.40146028297691116, 1.6351055793339955, 0.454031792332478, 1.8890189756323954e-06, 6.721993958121896e-05, 1.2284361851482313e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362211569163446
# En la iteración 5 obtenemos:
# Suma de fracciones molares: 1.0009538891235843
# Temperatura de combustión inicial: 1560.5715683819171K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041848047289550654, 0.493750715287085, 0.0027696234930826504, 0.8787753225588171, 0.4014567620251919, 1.6350997972362877, 0.45403893917506655, 1.8875871679165325e-06, 6.727821064744846e-05, 1.2275057838852352e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362217856728582
# En la iteración 6 obtenemos:
# Suma de fracciones molares: 1.000954926378554
# Temperatura de combustión inicial: 1560.5756442603358K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041816326680461674, 0.4937540894322915, 0.002770247363292458, 0.8787846491437586, 0.4014531985622735, 1.6350939900858261, 0.45404607150211446, 1.8861564618071955e-06, 6.73359473082692e-05, 1.226576098455862e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362224151306494
# En la iteración 7 obtenemos:
# Suma de fracciones molares: 1.000955911014794
# Temperatura de combustión inicial: 1560.5793870221091K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041784628527139145, 0.49375738990311946, 0.0027708314583598076, 0.8787939455971788, 0.40144959418051657, 1.6350881587338508, 0.4540531903434753, 1.8847267685284184e-06, 6.739317521639959e-05, 1.225647071172706e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362230452929439
# En la iteración 8 obtenemos:
# Suma de fracciones molares: 1.0009568452762476
# Temperatura de combustión inicial: 1560.582810662266K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004175295097484207, 0.4937606198802496, 0.0027713774111051766, 0.8788032136028776, 0.40144595039999237, 1.6350823039943785, 0.4540602966774429, 1.8832980044251455e-06, 6.744991955788697e-05, 1.2247186476759756e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362236761625986
# En la iteración 9 obtenemos:
# Suma de fracciones molares: 1.0009577334213722
# Temperatura de combustión inicial: 1560.5859285212796K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041721214640411277, 0.49376379007711624, 0.002771887986238285, 0.8788124773956791, 0.40144225959970825, 1.6350764122292345, 0.4540674088192492, 1.881866589050027e-06, 6.750632961715683e-05, 1.2237885013594503e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362243092926439
# En la iteración 10 obtenemos:
# Suma de fracciones molares: 1.0009585751560213
# Temperatura de combustión inicial: 1560.5887599419552K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004168949545334739, 0.4937668954066986, 0.0027723632942496723, 0.8788217157768753, 0.4014385320489448, 1.6350704984763413, 0.4540745102387667, 1.8804359470788006e-06, 6.756231468300027e-05, 1.2228588576075859e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3622494314036135
# En la iteración 11 obtenemos:
# Suma de fracciones molares: 1.0009593724436527
# Temperatura de combustión inicial: 1560.591309101551K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004165779163885689, 0.49376993866836555, 0.002772804765733504, 0.878830930265911, 0.4014347690580543, 1.6350645634186156, 0.4540816018259635, 1.879005998462315e-06, 6.761788358142158e-05, 1.2219296644037383e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362255777116848
# En la iteración 12 obtenemos:
# Suma de fracciones molares: 1.0009601271594755
# Temperatura de combustión inicial: 1560.5935876908586K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041626101548859464, 0.4937729225285173, 0.002773213765470281, 0.878840122296477, 0.40143097188413135, 1.6350586077184224, 0.45408868441631167, 1.8775766688666071e-06, 6.767305766993725e-05, 1.2210008734450433e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3622621301113735
# En la iteración 13 obtenemos:
# Suma de fracciones molares: 1.0009608419914002
# Temperatura de combustión inicial: 1560.595606859582K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041594382805875394, 0.4937758532720096, 0.0027735920651944584, 0.8788493050432931, 0.4014271367728129, 1.635052624312347, 0.4540957679188471, 1.8761460469248747e-06, 6.772792358996038e-05, 1.2200712427085196e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362268498638071
# En la iteración 14 obtenemos:
# Suma de fracciones molares: 1.0009615176629145
# Temperatura de combustión inicial: 1560.5973794038111K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041562674360126037, 0.49377872949143997, 0.0027739403696856, 0.8788584680745047, 0.401423269695926, 1.6350466213777624, 0.45410284405395157, 1.8747158894230453e-06, 6.778243902184483e-05, 1.2191419137691361e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362274874633526
# En la iteración 15 obtenemos:
# Suma de fracciones molares: 1.0009621558208501
# Temperatura de combustión inicial: 1560.5989127619587K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004153097430539552, 0.49378155356018966, 0.0027742598762389454, 0.8788676127808115, 0.40141937169263947, 1.635040599406076, 0.45410991365693415, 1.8732861103843742e-06, 6.78366187952688e-05, 1.2182128307584464e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362281258237335
# En la iteración 16 obtenemos:
# Suma de fracciones molares: 1.0009627663035148
# Temperatura de combustión inicial: 1560.6002167024549K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004149883511555868, 0.4937843664402184, 0.002774555654891952, 0.878876868756732, 0.40141538831838286, 1.63503447402384, 0.4541170768359376, 1.8718365248761088e-06, 6.789120864011104e-05, 1.2172708773293881e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362287739611477
# En la iteración 17 obtenemos:
# Suma de fracciones molares: 1.0009633414260792
# Temperatura de combustión inicial: 1560.6013145488075K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004146669943722831, 0.49378713039729466, 0.0027748241427738188, 0.8788861089896858, 0.4014113749660388, 1.6350283297589363, 0.45412423522903245, 1.870387097748591e-06, 6.794552754137376e-05, 1.2163290268175332e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362294229381765
# Archivo generado exitosamente en:
#  0.0124 8.23 1560.6 33.924 0.0216224 384.5157 1.3246 891.57 0.0004146669943722831 0.49378713039729466 0.0027748241427738188 0.8788861089896858 0.4014113749660388 1.6350283297589363 0.45412423522903245 1.870387097748591e-06 6.794552754137376e-05 1.2163290268175332e-07 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.0009675385237318
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004145131873518045, 0.49378842645092735, 0.002774932542109495, 0.8788905132844015, 0.4014094332055749, 1.6350253823948975, 0.45412762136033, 1.8363578728728755e-05, 6.874836777530801e-05, 1.1962334948596798e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362297363344436
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.0009274748030839
# Temperatura de combustión inicial: 1560.5871873208694K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041434638827282113, 0.4937906455160622, 0.0027754209742865427, 0.8788956649626659, 0.40140792303241174, 1.634765910107519, 0.4541323732525405, 1.921590261420605e-06, 6.557948613307741e-05, 1.1622794723459364e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362204067279787
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.000931954789401
# Temperatura de combustión inicial: 1560.427760526211K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041376721863590116, 0.4937979095021956, 0.0027768950237157673, 0.8789133730645812, 0.40140237603149226, 1.634761213678089, 0.4541485151678984, 1.912829263333916e-06, 6.561850962648399e-05, 1.1606313076565764e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362216308807233
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.0009331366736334
# Temperatura de combustión inicial: 1560.4433132409536K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041359159125252393, 0.49380002168341314, 0.0027772929281335416, 0.8789187083465609, 0.40140063643252644, 1.6347589716148425, 0.4541533760651604, 1.912017387231348e-06, 6.567225896534578e-05, 1.1601390911341097e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362219751823278
# En la iteración 5 obtenemos:
# Suma de fracciones molares: 1.000934221378661
# Temperatura de combustión inicial: 1560.4470662252909K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041342611505339503, 0.49380198241958817, 0.0027776517730601262, 0.8789237241697632, 0.4013989787717379, 1.6347568419995506, 0.45415794603458526, 1.9112524372045707e-06, 6.57046593496499e-05, 1.1596753245066051e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.36222300127638
# En la iteración 6 obtenemos:
# Suma de fracciones molares: 1.0009349379045076
# Temperatura de combustión inicial: 1560.4504732743403K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004133148463261577, 0.49380328520251227, 0.0027778845037048014, 0.8789270909855116, 0.4013978542035503, 1.6347554008152363, 0.45416101360918054, 1.9107380731067098e-06, 6.572790830618756e-05, 1.1593634807330037e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3622251891713955
# En la iteración 7 obtenemos:
# Suma de fracciones molares: 1.0009358412001546
# Temperatura de combustión inicial: 1560.4526920644469K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004131720855875437, 0.49380493867029657, 0.0027781732280077118, 0.8789314039039592, 0.4013963998876487, 1.6347535410920555, 0.45416494319979056, 1.910078130278668e-06, 6.57542264691725e-05, 1.1589633768713273e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362227999681714
# En la iteración 8 obtenemos:
# Suma de fracciones molares: 1.0009369481723644
# Temperatura de combustión inicial: 1560.4554571577946K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.000412993353993662, 0.4938069805914808, 0.0027785192743330265, 0.8789367929281907, 0.40139456120604267, 1.6347511952857094, 0.4541698531986415, 1.9092519042821514e-06, 6.578718012514231e-05, 1.1584624604316253e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3622315233634215
# En la iteración 9 obtenemos:
# Suma de fracciones molares: 1.000937866641678
# Temperatura de combustión inicial: 1560.4587891557237K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041284183822606327, 0.4938086876486454, 0.002778799509463531, 0.8789413523532151, 0.40139298724177475, 1.6347491921262058, 0.4541740072374083, 1.908551489412265e-06, 6.581675913712861e-05, 1.1580378195653085e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362234514934615
# En la iteración 10 obtenemos:
# Suma de fracciones molares: 1.0009380477679215
# Temperatura de combustión inicial: 1560.4615031712815K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004128117385667082, 0.4938090242130946, 0.0027788537798549232, 0.8789422571545917, 0.4013926729321643, 1.6347487930793738, 0.45417483157524463, 1.9084123471346577e-06, 6.58260059470166e-05, 1.157953461708519e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.36223510987856
# Archivo generado exitosamente en:
#  0.0192 8.29 1560.46 33.9213 0.0216225 384.5143 1.3247 891.54 0.0004128117385667082 0.4938090242130946 0.0027788537798549232 0.8789422571545917 0.4013926729321643 1.6347487930793738 0.45417483157524463 1.9084123471346577e-06 6.58260059470166e-05 1.157953461708519e-07 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.0009421344700387
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004128117025576923, 0.49380902428220824, 0.002778853790490917, 0.8789422573417826, 0.4013926728662615, 1.6347487927956093, 0.45417483174472134, 1.8783585101312994e-05, 6.678028450650892e-05, 1.1349817415062998e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362235109927937
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.000904184687625
# Temperatura de combustión inicial: 1560.4463168970901K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.000412334577889045, 0.49381692299051977, 0.002780767834720434, 0.8789583632462223, 0.4013891219990196, 1.6344714895899184, 0.4541916585788851, 1.9725352149276716e-06, 6.322362748884506e-05, 1.1239676757062521e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362141785668794
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.000912699736364
# Temperatura de combustión inicial: 1560.2919350892257K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041159342488284703, 0.4938278047702044, 0.002783175000741746, 0.8789818546879928, 0.4013833507503769, 1.6344690072173091, 0.4542161004171286, 1.963097154100083e-06, 6.328422372659679e-05, 1.1219241496576927e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.36215690642346
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.0009142145778411
# Temperatura de combustión inicial: 1560.3208710002484K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004114479051107, 0.49382982853239865, 0.0027835865752843625, 0.8789864217813201, 0.40138214521541515, 1.6344679588886388, 0.4542208487285773, 1.962403131915229e-06, 6.335260776369523e-05, 1.1215278443315586e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362159714888203
# En la iteración 5 obtenemos:
# Suma de fracciones molares: 1.0009170488438586
# Temperatura de combustión inicial: 1560.3256718240816K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004111665758896718, 0.4938336561594561, 0.0027843360927167988, 0.8789952172272363, 0.4013797600111012, 1.6344658745300085, 0.4542299911071803, 1.9610613986390196e-06, 6.340400402702914e-05, 1.1207616785587178e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362165160428091
# En la iteración 6 obtenemos:
# Suma de fracciones molares: 1.0009182005616488
# Temperatura de combustión inicial: 1560.3345828622262K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041104965754928615, 0.49383521494095245, 0.0027846301957487603, 0.8789988597469186, 0.4013787481444804, 1.6344649863311667, 0.4542337763884819, 1.9605037842279453e-06, 6.343613880611826e-05, 1.1204432657387006e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362167429608341
# En la iteración 7 obtenemos:
# Suma de fracciones molares: 1.0009187154459884
# Temperatura de combustión inicial: 1560.3381342220798K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004109968293505746, 0.49383591326688586, 0.0027847598206672615, 0.879000503176125, 0.40137828707640716, 1.6344645812294807, 0.454235484035043, 1.9602518326109592e-06, 6.344991370255197e-05, 1.1202993945917726e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362168456190727
# En la iteración 8 obtenemos:
# Suma de fracciones molares: 1.000919085987361
# Temperatura de combustión inicial: 1560.3397114225115K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004109584864001444, 0.4938364183080862, 0.002784852918903136, 0.8790016952611683, 0.4013779512629844, 1.634464287031595, 0.45423672263983295, 1.96006896496461e-06, 6.345253112425425e-05, 1.1201949722493583e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362169202040465
# En la iteración 9 obtenemos:
# Suma de fracciones molares: 1.000920661658528
# Temperatura de combustión inicial: 1560.3408507044735K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041079359307634445, 0.4938385658173144, 0.0027852399890132, 0.8790068120216136, 0.4013764913178467, 1.6344629990494217, 0.45424203820227, 1.959282545200733e-06, 6.348561102895743e-05, 1.1197459054215192e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362172412071038
# En la iteración 10 obtenemos:
# Suma de fracciones molares: 1.0009223508860585
# Temperatura de combustión inicial: 1560.3456257274895K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041061298479522495, 0.4938408776950618, 0.002785641991388466, 0.8790124002765101, 0.4013748661350253, 1.6344615599846042, 0.4542478420007757, 1.9584211766594345e-06, 6.352110218211354e-05, 1.119254040826794e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362175935777417
# En la iteración 11 obtenemos:
# Suma de fracciones molares: 1.0009234204957647
# Temperatura de combustión inicial: 1560.3506678858294K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041049658696208445, 0.4938423458225415, 0.002785889176842906, 0.8790159930269863, 0.4013738045819397, 1.6344606172194138, 0.45425157238660663, 1.9578660446847346e-06, 6.354710530184256e-05, 1.1189370455446862e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362178211000129
# En la iteración 12 obtenemos:
# Suma de fracciones molares: 1.0009247327816468
# Temperatura de combustión inicial: 1560.3538145939508K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041035132943234695, 0.49384415440318463, 0.002786184804987315, 0.8790204671215364, 0.4013724645163148, 1.634459424003623, 0.4542562167763429, 1.9571732732031143e-06, 6.357470856911552e-05, 1.1185414544037251e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362181054970398
# En la iteración 13 obtenemos:
# Suma de fracciones molares: 1.0009261561224374
# Temperatura de combustión inicial: 1560.3576328282752K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004101907819681827, 0.493846123576608, 0.002786495306190982, 0.8790254002214103, 0.40137096400395883, 1.6344580837269678, 0.454261336137567, 1.9564075799903777e-06, 6.360564753836028e-05, 1.1181042229938151e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362184204112374
# En la iteración 14 obtenemos:
# Suma de fracciones molares: 1.0009274158425077
# Temperatura de combustión inicial: 1560.3617133507503K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041004601056125517, 0.4938478730178842, 0.002786760980176986, 0.8790298380545066, 0.4013695938247181, 1.6344568562337733, 0.45426594010101456, 1.9557171269566854e-06, 6.363457830560659e-05, 1.1177099557489531e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362187049011828
# En la iteración 15 obtenemos:
# Suma de fracciones molares: 1.0009290441886638
# Temperatura de combustión inicial: 1560.3652696836768K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004098548701049778, 0.49385014555037204, 0.0027870914152740944, 0.8790356823494687, 0.40136776044645783, 1.6344552084010857, 0.45427200097888726, 1.9548055276934326e-06, 6.366989878876842e-05, 1.1171894080615506e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362190812510702
# En la iteración 16 obtenemos:
# Suma de fracciones molares: 1.0009294770087829
# Temperatura de combustión inicial: 1560.369791196807K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00040980345866598646, 0.4938507497393334, 0.002787176437787417, 0.8790372514702626, 0.4013672626962915, 1.6344547602754158, 0.45427362780678127, 1.9545603329773274e-06, 6.36850660107714e-05, 1.1170493952866825e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.36219182630537
# En la iteración 17 obtenemos:
# Suma de fracciones molares: 1.000929795768392
# Temperatura de combustión inicial: 1560.370972702189K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00040976520584721203, 0.49385119780511016, 0.002787238889235724, 0.8790384183831528, 0.40136689137248327, 1.634454427170783, 0.4542748375381693, 1.954377895192623e-06, 6.368711661996828e-05, 1.1169452184068243e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362192581450675
# Archivo generado exitosamente en:
#  0.0261 8.35 1560.37 33.9192 0.0216224 384.5156 1.3247 891.52 0.00040976520584721203 0.49385119780511016 0.002787238889235724 0.8790384183831528 0.40136689137248327 1.634454427170783 0.4542748375381693 1.954377895192623e-06 6.368711661996828e-05 1.1169452184068243e-07 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.0016130033928101
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003255361450811029, 0.4948248380080282, 0.002914737855903554, 0.881598017060105, 0.4005383004881826, 1.6337121902761358, 0.45691393991349105, 2.0556427246615105e-05, 6.0589277386412436e-05, 2.016446731679689e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363869970128633
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.0012353589453196
# Temperatura de combustión inicial: 1562.2213272435147K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003243476746414103, 0.49477654747616157, 0.002904097486402173, 0.8816127484207131, 0.40049046753748946, 1.6312245685420323, 0.45697619581966986, 2.3114215664214596e-06, 5.592547178279222e-05, 2.0039899233279754e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362977566983849
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.0012417594819105
# Temperatura de combustión inicial: 1560.2752412114673K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003171268100407195, 0.4944825351260538, 0.002839444332701194, 0.8816991194123358, 0.4001931313291316, 1.6320972183849483, 0.4572993934891044, 2.2487364890451484e-06, 5.479729117569147e-05, 1.9591513136216338e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363566710589288
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.0012127275478275
# Temperatura de combustión inicial: 1559.5000737935584K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00031503851284139014, 0.4944425436412391, 0.0028207464343607026, 0.8817381899403421, 0.4001263008128881, 1.6321379110961869, 0.457334231157095, 2.220251725267047e-06, 5.444058393091175e-05, 1.9459387179357353e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363679862345515
# En la iteración 5 obtenemos:
# Suma de fracciones molares: 1.0012046504035106
# Temperatura de combustión inicial: 1559.314742916642K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00031456459817694567, 0.4944364713574966, 0.002816503164890092, 0.8817482870857827, 0.40011279205391687, 1.632127589124668, 0.457341681220527, 2.2116713858456012e-06, 5.43993808314993e-05, 1.9428873686691296e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363697963533842
# En la iteración 6 obtenemos:
# Suma de fracciones molares: 1.0012019454375982
# Temperatura de combustión inicial: 1559.271474213959K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00031441031206896084, 0.4944347243931045, 0.002815121739823775, 0.8817516722715371, 0.4001085298929585, 1.6321227966507537, 0.45734415740527407, 2.210185823973451e-06, 5.437707685310799e-05, 1.9419252733926063e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.36370326099514
# En la iteración 7 obtenemos:
# Suma de fracciones molares: 1.0012006875928476
# Temperatura de combustión inicial: 1559.2573414768653K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00031433835165654974, 0.4944339444911333, 0.002814477430871925, 0.8817532661264409, 0.4001065628375101, 1.63212043557868, 0.45734532267581735, 2.209679992161213e-06, 5.4370286558252146e-05, 1.9414810455088705e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363705674444621
# En la iteración 8 obtenemos:
# Suma de fracciones molares: 1.0011999056860164
# Temperatura de combustión inicial: 1559.2508052274447K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00031429337170056724, 0.49443346702954605, 0.0028140746957107114, 0.8817542666970294, 0.40010533930414754, 1.6321189426114617, 0.4573460541700727, 2.2093638142532952e-06, 5.436916304345109e-05, 1.941203374078327e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363707173577179
# En la iteración 9 obtenemos:
# Suma de fracciones molares: 1.0011994425584807
# Temperatura de combustión inicial: 1559.2467482619236K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00031426668490730676, 0.4944331868929005, 0.00281383575127977, 0.8817548616910105, 0.40010461525893254, 1.6321180552896744, 0.4573464891594886, 2.209176224597463e-06, 5.4364546540089895e-05, 1.9410386304742176e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363708061493081
# En la iteración 10 obtenemos:
# Suma de fracciones molares: 1.001199046498114
# Temperatura de combustión inicial: 1559.2443543713184K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00031424367580931516, 0.49443294764154844, 0.002813629735676006, 0.8817553756690821, 0.40010399235871086, 1.6321172897882643, 0.45734686492408905, 2.2090144865897846e-06, 5.4368973130289036e-05, 1.9408965901138997e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3637088261836325
# En la iteración 11 obtenemos:
# Suma de fracciones molares: 1.0011990465419236
# Temperatura de combustión inicial: 1559.2422969822646K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003142436740879639, 0.4944329476237428, 0.002813629720263615, 0.8817553757075738, 0.40010399231216637, 1.6321172897309182, 0.4573468649522302, 2.2090144744898787e-06, 5.4369293733405404e-05, 1.9408965794876096e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363708826240783
# Archivo generado exitosamente en:
#  0.0329 8.4 1559.24 33.9041 0.0216044 384.8361 1.3249 891.63 0.0003142436740879639 0.4944329476237428 0.002813629720263615 0.8817553757075738 0.40010399231216637 1.6321172897309182 0.4573468649522302 2.2090144744898787e-06 5.4369293733405404e-05 1.9408965794876096e-07 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.0012028648824454
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003141787438275796, 0.49443226575786686, 0.0028130491810895567, 0.8817568158087348, 0.40010222876017343, 1.6321151234890638, 0.45734789825992417, 2.198659024190063e-05, 5.621473156110196e-05, 1.8898231889682703e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363710995690945
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.0010819700142053
# Temperatura de combustión inicial: 1559.2178388094783K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.000314209789907945, 0.4944325869091166, 0.002813327982218399, 0.8817561213604987, 0.40010307206232715, 1.631309933553704, 0.45734739988902345, 2.3654117520880594e-06, 5.0280559227212565e-05, 1.8881184822453188e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363408409370954
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.0010964139343916
# Temperatura de combustión inicial: 1558.6766982649128K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00031271875965155804, 0.4944452046240541, 0.0028011626111521526, 0.8818020411409856, 0.40008304515326937, 1.6313508313963654, 0.45740731436341187, 2.3477614851215515e-06, 5.0079486261550915e-05, 1.8789914039764625e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.36347076314875
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.0010964464516763
# Temperatura de combustión inicial: 1558.7236092655326K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003127109677073575, 0.4944452553614508, 0.0028010928151828048, 0.8818022736981558, 0.4000829279384037, 1.6313507711299433, 0.4574076059949477, 2.3477029889406257e-06, 5.013944956947841e-05, 1.8789446104648597e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3634710007570385
# Archivo generado exitosamente en:
#  0.0398 8.46 1558.72 33.8952 0.0216045 384.8335 1.325 891.52 0.0003127109677073575 0.4944452553614508 0.0028010928151828048 0.8818022736981558 0.4000829279384037 1.6313507711299433 0.4574076059949477 2.3477029889406257e-06 5.013944956947841e-05 1.8789446104648597e-07 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.0011017706335248
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00031271093577007596, 0.49444525538577677, 0.0028010927798405015, 0.881802273812255, 0.4000829278799356, 1.6313507707801473, 0.4574076061371192, 2.3514392619644772e-05, 5.221015226531537e-05, 1.826089103836785e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.36347100075577
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.0012237223222316
# Temperatura de combustión inicial: 1558.703616539685K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003126222094282877, 0.4944447027280292, 0.002800299269687773, 0.8818044085118706, 0.40008077567896816, 1.6322501774186666, 0.45740946898568713, 2.5419771123996026e-06, 4.600992747506101e-05, 1.5956233969876538e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363811073348807
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.0012238581510653
# Temperatura de combustión inicial: 1559.3490832572875K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00031262211226430726, 0.4944447026808283, 0.0028002992084762333, 0.8818044085809816, 0.4000807755784316, 1.6322501772678661, 0.4574094690221207, 2.550810457313056e-06, 4.660476727576389e-05, 1.4908021688611698e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363811073456959
# Archivo generado exitosamente en:
#  0.0466 8.51 1559.35 33.9057 0.0216035 384.8512 1.3249 891.67 0.00031262211226430726 0.4944447026808283 0.0028002992084762333 0.8818044085809816 0.4000807755784316 1.6322501772678661 0.4574094690221207 2.550810457313056e-06 4.660476727576389e-05 1.4908021688611698e-07 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.000767706933933
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00029209053258759366, 0.4941511729846495, 0.0026164156445707878, 0.8822238062629367, 0.3994611344655972, 1.6314266377811062, 0.4576227078409554, 2.5655522940544563e-05, 4.755356085247951e-05, 7.837201706808755e-10, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.364516505895077
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.0008044582408009
# Temperatura de combustión inicial: 1557.0560758505642K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0002922720725576583, 0.49415199705598556, 0.002616716806960502, 0.8822244768638714, 0.39946138808232917, 1.6317291086776395, 0.4576231866882601, 2.865655691340228e-06, 3.891422734519239e-05, 4.98643586872318e-08, 1.0012428353434526e-10, 0.5]
# Suma de coeficientes (N_m): 4.364629813673469
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.000808135282158
# Temperatura de combustión inicial: 1557.294497861099K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0002931159538609526, 0.49415788659608484, 0.0026188262099119206, 0.8822294973756571, 0.39946295645571617, 1.6317288152252045, 0.45762621692245825, 2.87251379811467e-06, 3.904970879499094e-05, 4.948262346947705e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.36463207337198
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.0008285074812415
# Temperatura de combustión inicial: 1557.3177172057117K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00029731128111194365, 0.4941917229230168, 0.002630587998492841, 0.8822593177345998, 0.3994713140241091, 1.6317252381333938, 0.4576443069651912, 2.866999927106168e-06, 3.9139489714403536e-05, 4.938782883506512e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.364645713410857
# En la iteración 5 obtenemos:
# Suma de fracciones molares: 1.0008302428377391
# Temperatura de combustión inicial: 1557.4486180532992K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00029762079049466583, 0.4941946210961882, 0.0026315681526216093, 0.882261946831937, 0.3994719797222278, 1.631724888331688, 0.4576459090828219, 2.8698008327901476e-06, 3.923381779184982e-05, 4.913449885695252e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.364646969975022
# En la iteración 6 obtenemos:
# Suma de fracciones molares: 1.0008314491245056
# Temperatura de combustión inicial: 1557.4596602384993K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0002978335247492295, 0.49419666958104935, 0.002632257651763807, 0.8822638142092655, 0.3994724441612952, 1.6317246111227555, 0.45764704788618166, 2.8694466273821375e-06, 3.924542879107293e-05, 4.9128446558930464e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.364647859599287
# En la iteración 7 obtenemos:
# Suma de fracciones molares: 1.0008340672912661
# Temperatura de combustión inicial: 1557.4674497699596K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00029828114518475865, 0.4942011364049836, 0.002633752241932335, 0.8822679106729473, 0.39947344043300065, 1.6317239827382986, 0.4576495484988638, 2.868666348405898e-06, 3.926635603165637e-05, 4.911511395361843e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.364649824716079
# En la iteración 8 obtenemos:
# Suma de fracciones molares: 1.000838279643172
# Temperatura de combustión inicial: 1557.484383878056K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.000298961802833388, 0.4942083754392567, 0.0026361499167473676, 0.8822746171854043, 0.3994750096048784, 1.6317228984972778, 0.457653649100117, 2.8673799885682385e-06, 3.930072500765394e-05, 4.909313395860734e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3646530790189955
# En la iteración 9 obtenemos:
# Suma de fracciones molares: 1.0008423164598186
# Temperatura de combustión inicial: 1557.5116823325536K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00029956544223461596, 0.49421537255952025, 0.002638437786204568, 0.8822811817724546, 0.3994764711594174, 1.631721770639257, 0.4576576711660751, 2.866110122319842e-06, 3.934510377862994e-05, 4.907143578909998e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.364656309059928
# En la iteración 10 obtenemos:
# Suma de fracciones molares: 1.0008431071263382
# Temperatura de combustión inicial: 1557.5378889852893K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00029967721506403086, 0.494216742523857, 0.002638882222326436, 0.8822824767743068, 0.39947675078400824, 1.6317215403273784, 0.4576584655781093, 2.865858361584208e-06, 3.937437364247341e-05, 4.906713396036534e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.364656951444404
# En la iteración 11 obtenemos:
# Suma de fracciones molares: 1.0008446624182519
# Temperatura de combustión inicial: 1557.5429929183088K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00029989285557023565, 0.4942194631209441, 0.002639761363182486, 0.8822850581133299, 0.3994772996311733, 1.631721073844644, 0.4576600500606413, 2.865355296175953e-06, 3.938637550968735e-05, 4.905853809563166e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.364658237097439
# En la iteración 12 obtenemos:
# Suma de fracciones molares: 1.000849902930312
# Temperatura de combustión inicial: 1557.5531222079337K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003005613979940238, 0.49422871013218417, 0.0026427142607072123, 0.8822939297255743, 0.399479099278821, 1.6317193933781176, 0.45766550569519027, 2.86361388033732e-06, 3.942042761906617e-05, 4.902878257130199e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.364662707414016
# En la iteración 13 obtenemos:
# Suma de fracciones molares: 1.0008506334273288
# Temperatura de combustión inicial: 1557.587343033386K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003006462786382871, 0.4942299957952177, 0.002643120410373164, 0.88229517547306, 0.39947934123192763, 1.6317191477780497, 0.4576662730278842, 2.863367805337865e-06, 3.945758336613826e-05, 4.9024577894583906e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3646633415335545
# En la iteración 14 obtenemos:
# Suma de fracciones molares: 1.0008513544886732
# Temperatura de combustión inicial: 1557.5920648604395K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003007289926629167, 0.4942312788975894, 0.002643524659779108, 0.8822964217834273, 0.3994795806546895, 1.6317188998786558, 0.4576670410205215, 2.8631212398126064e-06, 3.946571286938707e-05, 4.902036483626497e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.364663977572942
# En la iteración 15 obtenemos:
# Suma de fracciones molares: 1.0008520698452419
# Temperatura de combustión inicial: 1557.5967796036575K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00030080921480813593, 0.49423255428709695, 0.0026439253895751405, 0.8822976636425175, 0.3994798165916467, 1.6317186505359562, 0.45766780658384254, 2.862875176886391e-06, 3.947377723559402e-05, 4.9016160365842e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.364664612912759
# En la iteración 16 obtenemos:
# Suma de fracciones molares: 1.000852779561851
# Temperatura de combustión inicial: 1557.6014595158254K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003008869728941218, 0.49423382204040134, 0.0026443226365055854, 0.8822989010914037, 0.39948004907950474, 1.6317183997684968, 0.4576685697408728, 2.862629612733837e-06, 3.948180181335815e-05, 4.901196441795079e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.364665247556032
# En la iteración 17 obtenemos:
# Suma de fracciones molares: 1.0008534837055378
# Temperatura de combustión inicial: 1557.6061049443556K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00030096229528495886, 0.4942350822490846, 0.0026447164416179836, 0.8823001341857335, 0.3994802781573252, 1.6317181475914855, 0.457669330523852, 2.862384540513431e-06, 3.948978718456316e-05, 4.900777687569061e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.364665881513896
# En la iteración 18 obtenemos:
# Suma de fracciones molares: 1.000854182341781
# Temperatura de combustión inicial: 1557.6107162975486K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003010352097731932, 0.4942363350022436, 0.002645106845278391, 0.8823013629796451, 0.399480503863314, 1.6317178940201573, 0.4576700889638509, 2.862139953547213e-06, 3.9497733824129674e-05, 4.900359762495534e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3646665147969355
# En la iteración 19 obtenemos:
# Suma de fracciones molares: 1.0008548755351467
# Temperatura de combustión inicial: 1557.6152939735098K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003011057436826521, 0.4942375803880995, 0.002645493887130632, 0.8823025875267135, 0.3994807262351776, 1.6317176390690065, 0.45767084509213224, 2.8618958452398155e-06, 3.950564219439149e-05, 4.899942655305011e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.364667147416024
# En la iteración 20 obtenemos:
# Suma de fracciones molares: 1.000855563348836
# Temperatura de combustión inicial: 1557.619838365524K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003011739238187224, 0.49423881849276224, 0.002645877605983301, 0.882303807879399, 0.3994809453097112, 1.6317173827525608, 0.4576715989389501, 2.8616522091189486e-06, 3.951351275427649e-05, 4.8995263549383086e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.364667779381528
# En la iteración 21 obtenemos:
# Suma de fracciones molares: 1.0008562458451125
# Temperatura de combustión inicial: 1557.6243498579836K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00030123977649679353, 0.49424004940119254, 0.0026462580399873536, 0.8823050240893306, 0.3994811611231686, 1.6317171250852243, 0.45767235053416494, 2.8614090388239795e-06, 3.9521345949352935e-05, 4.899110850527031e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.364668410703704
# En la iteración 22 obtenemos:
# Suma de fracciones molares: 1.000856923085109
# Temperatura de combustión inicial: 1557.6288288299227K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00030130332757433083, 0.49424127319679034, 0.0026466352267340443, 0.8823062362075194, 0.3994813737111857, 1.6317168660807844, 0.457673099907179, 2.8611663280914182e-06, 3.952914222152903e-05, 4.89869613136877e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3646690413928475
# En la iteración 23 obtenemos:
# Suma de fracciones molares: 1.0008585491479662
# Temperatura de combustión inicial: 1557.6332756533411K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00030144817899965267, 0.4942442240100912, 0.00264754012086704, 0.8823091716872735, 0.3994818776622616, 1.6317162291130802, 0.45767491606824945, 2.86057697506413e-06, 3.954293617730587e-05, 4.8976891054791376e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.364670575227351
# En la iteración 24 obtenemos:
# Suma de fracciones molares: 1.0008611898995012
# Temperatura de combustión inicial: 1557.6439718987695K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# ...
# Suma de coeficientes (N_m): 4.378425824000305
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.0002493862203334
# Temperatura de combustión inicial: 1551.8872816031424K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00023724624268413137, 0.4979133553277443, 0.0011121005171920936, 0.8985785163950122, 0.39142459306611477, 1.617689713851198, 0.4725238221144889, 5.1445679333258056e-05, 4.033050281681002e-06, 2.8814146038686198e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.378442931824481
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.000250091541897
# Temperatura de combustión inicial: 1551.9666508862592K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00023760089194821557, 0.4979139815690985, 0.0011122938533322884, 0.8985790162587403, 0.3914247966868628, 1.6176902893764185, 0.4725246343143209, 5.154186931139645e-05, 4.033397937990192e-06, 6.408359860528163e-09, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.378443183119555
# En la iteración 5 obtenemos:
# Suma de fracciones molares: 1.000250092077768
# Temperatura de combustión inicial: 1551.9697563258892K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0002376008934396806, 0.4979139815717332, 0.0011122938541414935, 0.8985790162608501, 0.39142479668771446, 1.6176902893783525, 0.4725246343177529, 5.154420321513889e-05, 4.033397936196671e-06, 6.40835985772297e-09, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3784431831204405
# Archivo generado exitosamente en:
#  2.1529 4.02 1551.97 33.7041 0.0214694 387.2561 1.3275 893.21 0.0002376008934396806 0.4979139815717332 0.0011122938541414935 0.8985790162608501 0.39142479668771446 1.6176902893783525 0.4725246343177529 5.154420321513889e-05 4.033397936196671e-06 6.40835985772297e-09 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.0002631413310847
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00023760112811299538, 0.49791398199872633, 0.0011122939785379535, 0.8985790166123121, 0.3914247968114803, 1.617690289095839, 0.47252463489034163, 5.6623507013482464e-05, 5.606954819790246e-05, 2.4251038539703032e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.378443182554465
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.0002940218250884
# Temperatura de combustión inicial: 1551.9495962106553K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00023761622959885602, 0.49791400991928875, 0.0011123020271200793, 0.8985790397735255, 0.391424804652462, 1.6180322973058436, 0.47252467236496226, 1.7999813283142076e-05, 1.4177740791276776e-05, 2.264440428260427e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3785695475616295
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.0002940476010007
# Temperatura de combustión inicial: 1552.236651790895K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0002376162296242111, 0.4979140099193809, 0.001112302027139708, 0.8985790397736239, 0.39142480465246526, 1.618032297305268, 0.4725246723650884, 1.8050143811038248e-05, 1.4240314939652383e-05, 2.2601408267114364e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.378569547561475
# Archivo generado exitosamente en:
#  2.1543 3.28 1552.24 33.7082 0.0214692 387.259 1.3274 893.27 0.0002376162296242111 0.4979140099193809 0.001112302027139708 0.8985790397736239 0.39142480465246526 1.618032297305268 0.4725246723650884 1.8050143811038248e-05 1.4240314939652383e-05 2.2601408267114364e-08 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.0003153996284435
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0002376162304905508, 0.497914009922681, 0.001112302027820077, 0.8985790397771748, 0.3914248046525352, 1.6180322958499729, 0.4725246723696217, 5.914522952414743e-05, 6.663535013045822e-05, 2.2623590361519958e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.378569544925957
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.0003120869069881
# Temperatura de combustión inicial: 1552.1834648144386K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00023761929653209486, 0.4979140967809877, 0.0011123130265759031, 0.8985791520216635, 0.39142478585335005, 1.618136863203917, 0.47252479852094975, 8.7602173818431e-06, 3.637784138766841e-05, 2.2266621734569556e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.378608282813473
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.0003120946821946
# Temperatura de combustión inicial: 1552.3118675581047K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00023761929654054508, 0.49791409678123555, 0.0011123130266072552, 0.8985791520219846, 0.391424785853296, 1.618136863203585, 0.4725247985213103, 8.785547926118641e-06, 3.638655499692924e-05, 2.2266621732374983e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.378608282813626
# Archivo generado exitosamente en:
#  2.1557 2.64 1552.31 33.7095 0.0214691 387.2604 1.3274 893.29 0.00023761929654054508 0.49791409678123555 0.0011123130266072552 0.8985791520219846 0.391424785853296 1.618136863203585 0.4725247985213103 8.785547926118641e-06 3.638655499692924e-05 2.2266621732374983e-08 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.0003343209163182
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00023761929000825035, 0.49791409683667476, 0.0011123130286044935, 0.8985791520987105, 0.3914247858320481, 1.6181368626181374, 0.47252479859967955, 8.204167974287335e-05, 6.044499414867734e-05, 2.6129761226696384e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.378608280874855
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.0001492233784095
# Temperatura de combustión inicial: 1552.2378187032334K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00023762052598933772, 0.4979140807287602, 0.0011123121538794557, 0.8985791301712347, 0.3914247915677991, 1.616979414886264, 0.47252477577976937, 5.43135798954764e-05, 7.385950966379709e-06, 1.8945733591846865e-08, 1.0034736975510391e-10, 0.5]
# Suma de coeficientes (N_m): 4.37818051750253
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.0003349466810507
# Temperatura de combustión inicial: 1551.4693043442053K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00026690226119497316, 0.4979525213004845, 0.0011264376386934442, 0.8986039971142489, 0.39144402786474064, 1.6179723258274155, 0.4725748441974371, 5.4119906781186815e-05, 7.275841855945106e-06, 1.7206446894408054e-08, 1.0004601412129471e-10, 0.5]
# Suma de coeficientes (N_m): 4.3785358931940594
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.000335177898055
# Temperatura de combustión inicial: 1552.3495590375708K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00026690226089107444, 0.4979525213062867, 0.0011264376367389414, 0.8986039971258478, 0.391444027860556, 1.6179723257903598, 0.4725748442144601, 5.5104572651099655e-05, 7.305545182269667e-06, 1.523672472557598e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.378535893192459
# Archivo generado exitosamente en:
#  2.1571 2.1 1552.35 33.7095 0.0214693 387.2583 1.3274 893.29 0.00026690226089107444 0.4979525213062867 0.0011264376367389414 0.8986039971258478 0.391444027860556 1.6179723257903598 0.4725748442144601 5.5104572651099655e-05 7.305545182269667e-06 1.523672472557598e-08 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.0003577980924658
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0002669022420411319, 0.4979525213570378, 0.0011264375768961859, 0.8986039972988323, 0.3914440277500362, 1.6179723252812148, 0.47257484446694936, 6.8291960174569e-05, 9.307836907067179e-05, 9.755512138351946e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.378535892167364
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.0001588084097692
# Temperatura de combustión inicial: 1552.310933030044K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0002669027344454302, 0.49795251740898394, 0.0011264412824266291, 0.8986039856786688, 0.391444034653098, 1.61674292889906, 0.47257482690094343, 9.210418527348584e-06, 5.5930964832370595e-05, 8.463391746985901e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.378081587500152
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.0002679677406867
# Temperatura de combustión inicial: 1551.516050814811K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00027787188829126965, 0.4979650126255076, 0.0011309127941635869, 0.8986119594162401, 0.39145085632675036, 1.61739551999189, 0.47259344387878544, 9.041227462614857e-06, 5.587336310813405e-05, 8.436552633578901e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.378317328175283
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.0002685629699946
# Temperatura de combustión inicial: 1552.0350380017342K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0002781426079531496, 0.4979653576757695, 0.0011309768160754049, 0.8986122857588064, 0.3914509574988031, 1.6173962853268256, 0.47259414633207725, 9.121518966463327e-06, 5.61117912662953e-05, 8.295128106377537e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.378317614395722
# En la iteración 5 obtenemos:
# Suma de fracciones molares: 1.0002685629699946
# Temperatura de combustión inicial: 1552.036991801474K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0002781426079531496, 0.4979653576757695, 0.0011309768160754049, 0.8986122857588064, 0.3914509574988031, 1.6173962853268256, 0.47259414633207725, 9.121518966463327e-06, 5.61117912662953e-05, 8.295128106377537e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.378317614395722
# Archivo generado exitosamente en:
#  2.1586 1.64 1552.04 33.7038 0.0214701 387.243 1.3275 893.21 0.0002781426079531496 0.4979653576757695 0.0011309768160754049 0.8986122857588064 0.3914509574988031 1.6173962853268256 0.47259414633207725 9.121518966463327e-06 5.61117912662953e-05 8.295128106377537e-08 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.000296140401036
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0002781743505228347, 0.4979654013123814, 0.0011309825376751243, 0.8986123278356628, 0.3914509679023678, 1.6173963511825902, 0.4725942357561179, 0.00010906774105241055, 7.66570024251472e-05, 7.49876033058942e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.378317643965452
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.00010847925103
# Temperatura de combustión inicial: 1551.9399061976503K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00027816569221777407, 0.49796539000129164, 0.0011309805990225143, 0.898612317717704, 0.3914509647039993, 1.61628128280373, 0.4725942136796469, 5.508114639444967e-05, 1.2185731281038255e-05, 5.734096840057129e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.377905727581848
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.0002429532520531
# Temperatura de combustión inicial: 1551.228297381517K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00029006561068805703, 0.4979783910710926, 0.001135777985901673, 0.8986200786775913, 0.3914586411977607, 1.6171029728517903, 0.47261330051656447, 5.50298628738104e-05, 1.1988797009970358e-05, 5.017816908617048e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.37820259829004
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.0002430079911524
# Temperatura de combustión inicial: 1551.8693240141215K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00029006561095605874, 0.4979783910714003, 0.0011357779859719663, 0.898620078677844, 0.3914586411978891, 1.6171029728500799, 0.4726133005171546, 5.508773998881776e-05, 1.2170717746268844e-05, 5.00385822577257e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.378202598289344
# Archivo generado exitosamente en:
#  2.16 1.24 1551.87 33.7008 0.0214703 387.2404 1.3275 893.17 0.00029006561095605874 0.4979783910714003 0.0011357779859719663 0.898620078677844 0.3914586411978891 1.6171029728500799 0.4726133005171546 5.508773998881776e-05 1.2170717746268844e-05 5.00385822577257e-08 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.0002750464573742
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0002900657643311646, 0.4979783912459112, 0.0011357780160497107, 0.8986200788305626, 0.3914586412594076, 1.6171029730599928, 0.4726133008849041, 8.471222192438044e-05, 0.0001227334879765863, 1.3174134821806443e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3782025974983
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.0000433634843928
# Temperatura de combustión inicial: 1551.8091212735071K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00029058078822180805, 0.4979789251420258, 0.001135975977227611, 0.898620391827826, 0.39145896894123644, 1.6156968695480636, 0.47261411821016086, 1.3053427933425705e-05, 6.372868970958805e-05, 1.2674171037705808e-07, 4.290031588460673e-08, 0.5]
# Suma de coeficientes (N_m): 4.377682950608126
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.0000598125542965
# Temperatura de combustión inicial: 1550.911079798896K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00028927112522630737, 0.4979775680639793, 0.0011354978686603757, 0.8986195575924211, 0.39145816424973234, 1.6158228651507218, 0.472611947672458, 1.2762337684722198e-05, 6.372662120738679e-05, 1.2614527376746482e-07, 5.247539713062103e-07, 0.5]
# Suma de coeficientes (N_m): 4.377730168357947
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.0000603333990106
# Temperatura de combustión inicial: 1550.9924621585778K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0002895872186565841, 0.4979778974193605, 0.0011356174477141474, 0.8986197550557451, 0.39145836253739447, 1.6158234031898038, 0.472612459406413, 1.2775781565753162e-05, 6.379161882538838e-05, 1.2536827218426145e-07, 5.375346565285537e-07, 0.5]
# Suma de coeficientes (N_m): 4.37773018923614
# En la iteración 5 obtenemos:
# Suma de fracciones molares: 1.0000603333990106
# Temperatura de combustión inicial: 1550.9944974866726K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00028958721865658503, 0.4979778974193605, 0.0011356174477141479, 0.8986197550557451, 0.39145836253739447, 1.6158234031898038, 0.472612459406413, 1.2775781565753162e-05, 6.379161882538838e-05, 1.2536827218426145e-07, 5.375346565285909e-07, 0.5]
# Suma de coeficientes (N_m): 4.37773018923614
# Archivo generado exitosamente en:
#  2.1614 1.0 1550.99 33.6861 0.0214717 387.2135 1.3277 892.95 0.00028958721865658503 0.4979778974193605 0.0011356174477141479 0.8986197550557451 0.39145836253739447 1.6158234031898038 0.472612459406413 1.2775781565753162e-05 6.379161882538838e-05 1.2536827218426145e-07 5.375346565285909e-07 0.5
# Archivo generado exitosamente en: C:/Users/german.perez/OneDrive - Destinus NL BV/Escritorio/Personal/TFG/Fotos/6 - Resultados\resultados_equilibrio.txt

# %%
## Más ineficiente (25 min) de compilación


#/////////////////////////--RUTA DE ARCHIVOS DE BASES DE DATOS--//////////////////////////////////////////
ruta_archivos = {
    'Reactantes' : 'C:/Users/german.perez/OneDrive - Destinus NL BV/Escritorio/Personal/TFG/code/Bases de datos/Reactants.json',
    'Especies' : 'C:/Users/german.perez/OneDrive - Destinus NL BV/Escritorio/Personal/TFG/code/Bases de datos/Species.json',
    'Propulsantes' : 'C:/Users/german.perez/OneDrive - Destinus NL BV/Escritorio/Personal/TFG/code/Bases de datos/Propellants.json'
}

#/////////////////////////--RUTA DE ARCHIVOS DE PRESION Y TIEMPO--//////////////////////////////////////////

# Definir la ruta del archivo
file_path = r"C:/Users/german.perez/OneDrive - Destinus NL BV/Escritorio/Personal/TFG/Fotos/6 - Resultados/Resultados Equilibrio Químico/presion y tiempo.txt"

# Leer los datos asumiendo separador de espacios y punto decimal
df = pd.read_csv(file_path, sep='\s+', decimal='.', header=None)

# Definir los nombres de las columnas
df.columns = ['Tiempo', 'Presión']

#////////////////////////--ARREGLOS PARA EL GUARDADO--//////////////////////////////////////////////////////////////

# Definir el directorio donde se guardará el archivo
output_dir = "C:/Users/german.perez/OneDrive - Destinus NL BV/Escritorio/Personal/TFG/Fotos/6 - Resultados"  # Cambia esto a tu directorio deseado

# Crear el directorio si no existe
os.makedirs(output_dir, exist_ok=True)

# Ruta del archivo de salida con el valor del tiempo en el nombre
output_file = os.path.join(output_dir, f"resultados_equilibrio.txt")

output_text="""Tiempo Presión Temperatura Cp Mm Rg Gamma Vsound N_KOH N_K2CO3 N_K2O N_CO N_CO2 N_H2O N_H2 N_H N_OH N_O N_O2 N_N2"""

# Guardar en un archivo de texto
with open(output_file, "w") as f:
    f.write(output_text)

# Iterar sobre cada fila y mostrar los valores de Tiempo y Presión
for index, row in df.iterrows():

    #///////////////--DEFINICIÓN DE CONDICIONES Y REACCIÓN QUÍMICA--//////////////////////////////////////////

    ## Paso de tiempo
    tiempo = row['Tiempo']# En segundos

    ## Constantes universales
    R = 8.31415 # KJ/ Kmol K = J/mol K

    ## Temperaturas y presiones
    T_0 = 298.15 # K
    p = row['Presión'] # Presión de cámara
    p0 = 1.0  # Presión estándar

    ## Definición de mezcla de reactivos
    N_KNO3 = 1
    N_C6H14O6 = 0.2988

    ## Nombre de las especies de la reacción
    Reactantes = ['KNO3(s)','Sorbitol']
    coef_r = [N_KNO3,N_C6H14O6]
    Productos = ['KOH(L)','K2CO3(L)','K2O','CO','CO2','H2O','H2','H','OH','O','O2']						

    coef_p = [0.000360065792818802, 0.493640832027809, 0.00272566861913182,
                    0.87866000126, 0.40143172266, 1.63439159539, 0.45389515045,
                    0.00000846023, 0.00012044938, 0.00000013817, 0.0000000001]
    N_N2 = [0.5] # fracción molar de N2
    N_m = [4.3619322173912005] # suma de los coef, estequeométricos


    #////////////////////////--VALORES INICIALES--//////////////////////////////////////////////////////////////

    initial_guess = coef_p+N_m ## Composiciones de N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_m
    T_inicial_iteracion = 1559 # K : Temperatura única en la que se analiza Kp
    T_in_NRaphson = 1550 # K : Temperatura única en la que se analiza en el NRaphson
    x_tot_0 = 0.5 ## Valor inicial de la suma de fracciones molares

    #////////////////////////--TOLERANCIAS DE CONVERGENCIA--//////////////////////////////////////////////////////////

    tol_x = 0.01 # tolerancia de convergencia para la fracción molar
    tol_Tad = 0.001 # tolerancia de convergencia para la T_adiabática
    tol_NRaphson = 10 # Tolerancia de convergencia del NRaphson

    #////////////////////////--ARREGLOS PARA LA TEMP. ADIAB.--//////////////////////////////////////////////////////////

    indent_nogas = ['(L)','(s)','(a)','(b)'] # identificadores de no gas
        
    ################################################################################################################
    ################################################################################################################
    ################################################################################################################

    T = T_inicial_iteracion # Antes de entrar al bucle inicializo la temperatura
    T_nueva = T_inicial_iteracion + 100
    contador_iter = 0

    while abs(T-T_nueva) >= tol_Tad:

        contador_iter += 1
        print(f'En la iteración {contador_iter} obtenemos:')

        T = T_nueva # temperatura obtenida en el anterior bucle y la que se usa para la concentración de equilibrio

        ## Constantes de equilibrio
        K_p_H_O_OH = Kp_T(Eqn_1,coef_1,T,ruta_archivos)
        K_p_O_O2 = Kp_T(Eqn_2,coef_2,T,ruta_archivos)
        K_p_H_O2_OH_O = Kp_T(Eqn_3,coef_3,T,ruta_archivos)
        K_p_H_OH_H2O = Kp_T(Eqn_4,coef_4,T,ruta_archivos)
        K_p_H2_O_OH_H = Kp_T(Eqn_5,coef_5,T,ruta_archivos)
        K_p_H2_OH_H2O_H = Kp_T(Eqn_6,coef_6,T,ruta_archivos)
        K_p_H2O_O_OH = Kp_T(Eqn_7,coef_7,T,ruta_archivos)


        # Define the function to compute the residuals as the sum of squares of each equation
        def objective(vars):
            N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_m = vars
            
            eq1 = 2 * N_K2CO3 + 2 * N_K2O + N_KOH - 1*N_KNO3
            eq2 = N_CO + N_CO2 + N_K2CO3 - 6*N_C6H14O6
            eq3 = N_H + 2 * N_H2 + 2 * N_H2O + N_KOH + N_OH - 14*N_C6H14O6
            eq4 = N_CO + 2 * N_CO2 + N_H2O + 3 * N_K2CO3 + N_K2O + N_KOH + N_O + 2 * N_O2 + N_OH - 3*N_KNO3 - 6*N_C6H14O6

            eq5 = N_CO + N_CO2 + N_H + N_H2 + N_H2O + N_K2CO3 + N_K2O + N_KOH + N_O + N_O2 + N_OH - N_m + 0.5

            eq6 = (p0/p) * N_OH * N_m  - K_p_H_O_OH* (N_H * N_O)
            eq7 = (p0/p) * N_O2 * N_m  - K_p_O_O2*N_O**2
            eq8 = N_O * N_OH  - K_p_H_O2_OH_O*(N_H * N_O2)
            eq9 = (p0/p) * N_H2O * N_m - K_p_H_OH_H2O*(N_H * N_OH)
            eq10 = N_H * N_OH  - K_p_H2_O_OH_H*(N_H2 * N_O)
            eq11 = N_H * N_H2O - K_p_H2_OH_H2O_H*(N_H2 * N_OH)
            eq12 = N_OH**2 - K_p_H2O_O_OH*(N_H2O * N_O)

            # Return the sum of squares of the residuals
            return (eq1**2 + eq2**2 + eq3**2 + eq4**2 + eq5**2 +
                    eq6**2 + eq7**2 + eq8**2 + eq9**2 + eq10**2 + eq11**2 + eq12**2)

        x_tot = x_tot_0

        while abs(x_tot-1) >= tol_x:
            #print(x_tot-1,tolerancia)

            # Define bounds for each variable to be greater than zero
            bounds = [(1e-10, None)] * 12  # Use a small number close to zero to avoid division by zero in equations

            # Use 'L-BFGS-B' because it supports bounds
            solution_1 = minimize(objective, initial_guess, bounds=bounds, method='L-BFGS-B')

            #print("Solución:")
            #print(solution_1.x)  # Shows the optimized values of the variables

            initial_guess = solution_1.x.tolist()

            x_i = [0]*len(solution_1.x)
            x_tot = 0.5/solution_1.x[11] # aqui tengo en cuenta ya el nitrógeno
            for index,i in enumerate(solution_1.x):
                x_i[index] = solution_1.x[index]/solution_1.x[11]
                x_tot += x_i[index]
                if index == 10:
                    break

            print(f'Suma de fracciones molares: {x_tot}')

        
        print(f'Temperatura de combustión inicial: {T}K')
        print("Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2")
        print(solution_1.x.tolist()[:11]+N_N2)  # Shows the optimized values of the variables
        print(f'Suma de coeficientes (N_m): {solution_1.x.tolist()[11]}')


        Productos_tot = Productos + ['N2']

        coef_p_tot = solution_1.x.tolist()[:11]+N_N2

        ## Ahora calculamos la nueva temperatura de combustión adiabática para la siguiente iteración
        T_nueva = T_adiab(Reactantes,Productos_tot,coef_r,coef_p_tot,ruta_archivos,R,T,tol_NRaphson)

    Coef = solution_1.x.tolist()[:11]+N_N2
    N_m=solution_1.x.tolist()[11]

    Mm_i = Datos_ProductosComb(ruta_archivos,Productos,T_nueva,R)[0]  # Mm,e_i,a_i,b_i,Cp_i,Hs_i,S_i
    Cp_i = Datos_ProductosComb(ruta_archivos,Productos,T_nueva,R)[4]  # Mm,e_i,a_i,b_i,Cp_i,Hs_i,S_i

    ## Cálculo de Cp_mezcla, Mm_mezcla, Gamma_mezcla, Vsonido_mezcla

    indent_nogas = ['(L)','(s)','(a)','(b)'] # identificadores de no gas
    C_ng, Cp_gas,Cp_mix,Mm_ng,Mm_gas,Mm_mix,N_ng,N_gas = 0,0,0,0,0,0,0,0

    for index, i in enumerate(Productos):
        if any(ng in i for ng in indent_nogas): #si no es una especie gaseosa
            C_ng += (Coef[index])*Cp_i[index]
            Mm_ng += (Coef[index])*Mm_i[index]
            N_ng += Coef[index]
        else:
            Cp_gas += (Coef[index])*Cp_i[index]
            Mm_gas += (Coef[index])*Mm_i[index]
            N_gas += Coef[index]

        Cp_mix += C_ng + Cp_gas
        Mm_mix += Mm_ng + Mm_gas

    C_ng = C_ng/N_ng
    Cp_gas = Cp_gas/N_m #Cp_gas/N_gas
    Cp_mix = Cp_mix/N_m
    Mm_ng = Mm_ng/N_ng
    Mm_gas = Mm_gas/N_gas
    Mm_mix = Mm_mix/N_m

    Gamma_gas = Cp_gas / (Cp_gas-R)
    Gamma_mix = Cp_mix / (Cp_mix-R)

    Vsound_gas = np.sqrt(Gamma_gas*(R/(Mm_gas/1000))*T_nueva)
    Vsound_mix = np.sqrt(Gamma_mix*(R/(Mm_mix/1000))*T_nueva)

    # Datos a escribir en el archivo (El 11 es el numero de moles ojo)
    output_text = f"""
 {tiempo} {round(p, ndigits=2)} {round(T_nueva, ndigits=2)} {round(Cp_gas, ndigits=4)} {round(Mm_gas, ndigits=4)} {round(R/(Mm_gas/1000), ndigits=4)} {round(Gamma_gas, ndigits=4)} {round(Vsound_gas, ndigits=2)} {solution_1.x.tolist()[0]} {solution_1.x.tolist()[1]} {solution_1.x.tolist()[2]} {solution_1.x.tolist()[3]} {solution_1.x.tolist()[4]} {solution_1.x.tolist()[5]} {solution_1.x.tolist()[6]} {solution_1.x.tolist()[7]} {solution_1.x.tolist()[8]} {solution_1.x.tolist()[9]} {solution_1.x.tolist()[10]} {N_N2[0]}"""
    
    print(f"Archivo generado exitosamente en: {output_text}")
    
    # Guardar en un archivo de texto
    with open(output_file, "a") as f:
        f.write(output_text)

# Mostrar la ruta del archivo generado
print(f"Archivo generado exitosamente en: {output_file}")
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\german.perez\AppData\Local\Temp\ipykernel_57508\2767006338.py:14: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(file_path, sep='\s+', decimal='.', header=None)
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.0007756578582525
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003600657940146247, 0.4936408320317225, 0.002725668620744906, 0.8786600012642589, 0.40143172266060767, 1.6343915953015455, 0.45389515045442885, 8.072034602871264e-05, 0.00012968930053737897, 1.3822885263916453e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3619322171013835
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.0005345370203227
# Temperatura de combustión inicial: 1559.514975166331K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003600525048516974, 0.49364079102869973, 0.0027256516855024555, 0.878659957546894, 0.40143171558303997, 1.6329120808934636, 0.45389510393865157, 1.4736548304584455e-05, 6.893521393749401e-05, 1.3280542798635456e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361377839933713
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.00046189255981
# Temperatura de combustión inicial: 1558.5583103670813K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003557276450444657, 0.4936334851235282, 0.0027225120056609984, 0.878653913600127, 0.4014288548118312, 1.6324588293673465, 0.4538864113835555, 1.4357971260313207e-05, 6.908662358681066e-05, 1.300899046101371e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361208898779722
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.0008355002286253
# Temperatura de combustión inicial: 1558.2080287395006K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004196596938750516, 0.49373346640716975, 0.0027659090232345436, 0.8787314641785542, 0.4014722572323276, 1.634320667112818, 0.4540050187351537, 1.429706900223128e-05, 6.886343035627432e-05, 1.296016507163221e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361887374685354
# En la iteración 5 obtenemos:
# Suma de fracciones molares: 1.0008356742863136
# Temperatura de combustión inicial: 1559.9759886984618K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041965969401099067, 0.49373346640772436, 0.0027659090234253224, 0.8787314641793276, 0.40147225723231883, 1.634320667108554, 0.45400501873601684, 1.4911150880989092e-05, 6.900857928979983e-05, 1.2959053766385876e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361887374683268
# Archivo generado exitosamente en:
#  0.0 1.0 1559.98 33.9148 21.6237 384.4928 1.3248 891.4 0.00041965969401099067 0.49373346640772436 0.0027659090234253224 0.8787314641793276 0.40147225723231883 1.634320667108554 0.45400501873601684 1.4911150880989092e-05 6.900857928979983e-05 1.2959053766385876e-07 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.000929907034137
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004206353316674866, 0.4938329917289958, 0.0028052807807226014, 0.8788706730989605, 0.40146170252852026, 1.634432358607356, 0.45411705113766754, 1.0656802777753197e-05, 0.00011938312615545115, 1.3557957538253558e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362014600762142
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.00094830991107
# Temperatura de combustión inicial: 1560.3817939997914K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.000420407337811001, 0.4938350642754139, 0.0028053646118541783, 0.8788772934872612, 0.4014592158995072, 1.6345632910722452, 0.4541240681425678, 1.0563944393625814e-06, 0.00011962096608560974, 1.2863574511501454e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362068917735472
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.0009517406160044
# Temperatura de combustión inicial: 1560.4862466181928K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041986017738897063, 0.4938398002186447, 0.0028054393894625333, 0.8788930815654196, 0.401453083543623, 1.6345579946892133, 0.4541407342904476, 1.0550196711396568e-06, 0.0001200829312879186, 1.2846845571983366e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362079691980508
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.0009551584833145
# Temperatura de combustión inicial: 1560.4915279926142K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041926621987579065, 0.4938447120089816, 0.002805393683476919, 0.8789101259313804, 0.40144626673174383, 1.6345520443600434, 0.4541586788737623, 1.0535273228593178e-06, 0.0001202687597084189, 1.2828685853344664e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3620914498298555
# En la iteración 5 obtenemos:
# Suma de fracciones molares: 1.0009583502996493
# Temperatura de combustión inicial: 1560.4962501185025K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004186714432142713, 0.4938494098036757, 0.0028052253612721825, 0.8789271031862407, 0.40143928457573436, 1.634545877386471, 0.45417650061612924, 1.0520329164273612e-06, 0.00012045365952568261, 1.2810501089979633e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362103283281556
# En la iteración 6 obtenemos:
# Suma de fracciones molares: 1.0009611029178
# Temperatura de combustión inicial: 1560.4999019820261K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041812148327240607, 0.4938535725250221, 0.002804968864466342, 0.8789427268463652, 0.4014326989338007, 1.6345399805961363, 0.4541928531217101, 1.0506511142693178e-06, 0.0001206092823580328, 1.2793686557651614e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362114269588832
# En la iteración 7 obtenemos:
# Suma de fracciones molares: 1.0009636870776997
# Temperatura de combustión inicial: 1560.502382043814K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041757104502032426, 0.4938575797273097, 0.002804623215590968, 0.8789582987425317, 0.4014259921162343, 1.6345339133312062, 0.45420910385284896, 1.0492681103326732e-06, 0.00012077558039406188, 1.2776857401417396e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3621253109543465
# En la iteración 8 obtenemos:
# Suma de fracciones molares: 1.0009661408484374
# Temperatura de combustión inicial: 1560.5040718668395K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004170129304802405, 0.4938614934246994, 0.0028041889671734208, 0.8789740264687288, 0.4014190818321653, 1.6345276007586647, 0.4542254674510894, 1.0478658193343361e-06, 0.00012094214727109642, 1.275979354955729e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362136551235417
# Archivo generado exitosamente en:
#  0.0124 8.23 1560.51 33.9216 21.6231 384.5027 1.3247 891.53 0.0004170129304802405 0.4938614934246994 0.0028041889671734208 0.8789740264687288 0.4014190818321653 1.6345276007586647 0.4542254674510894 1.0478658193343361e-06 0.00012094214727109642 1.275979354955729e-07 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.0010860106935622
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004764798123088758, 0.4940067106288708, 0.002878007240079487, 0.8790573179037491, 0.4014912476921454, 1.6344713494681686, 0.4543133426383068, 9.455333757952789e-06, 0.0001191935737069834, 1.2509887838744503e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362085957493896
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.0009660015644248
# Temperatura de combustión inicial: 1561.1109137268008K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00047909935183824845, 0.4940156448167654, 0.00286972754717501, 0.8791122865222469, 0.4014693748134012, 1.6334929813633403, 0.4544051727944394, 9.455073819925698e-07, 0.00012062492095462033, 1.1495735310233628e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3617525129437595
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.0010069013168024
# Temperatura de combustión inicial: 1560.4404523762485K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00047895905961727324, 0.4940249259547136, 0.0028526663968816888, 0.8792045781144171, 0.40142601802923117, 1.6335783401324997, 0.45455419635793465, 9.316892692889652e-07, 0.00012036973316853928, 1.1401887000361122e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361849147935853
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.001011892325262
# Temperatura de combustión inicial: 1560.478239131933K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00047788449703242697, 0.4940258314815882, 0.0028471870976445133, 0.8792287336746499, 0.40141262710019016, 1.633577548092121, 0.4545910044605093, 9.295992134436332e-07, 0.00012077928328256227, 1.1376328869971067e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361868897488352
# En la iteración 5 obtenemos:
# Suma de fracciones molares: 1.0010166229014108
# Temperatura de combustión inicial: 1560.4633252147034K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004767783951849596, 0.4940268115141562, 0.0028415657226841824, 0.8792535372004906, 0.40139872872275817, 1.6335761211009112, 0.45462822782667, 9.274478128044955e-07, 0.00012099538713063938, 1.1350020588219103e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361889410250124
# En la iteración 6 obtenemos:
# Suma de fracciones molares: 1.001020518867243
# Temperatura de combustión inicial: 1560.4477140607653K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00047579815688796024, 0.4940277357704562, 0.0028366080862455324, 0.8792754752635668, 0.40138632598156515, 1.6335742331480463, 0.45466066972992664, 9.25541220474413e-07, 0.0001212173977061333, 1.1326705931109934e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.36190769334445
# En la iteración 7 obtenemos:
# Suma de fracciones molares: 1.0010241921492806
# Temperatura de combustión inicial: 1560.4335884116788K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00047480792701288594, 0.49402873304318445, 0.002831628693342227, 0.8792976033491222, 0.4013737245726901, 1.6335718288360876, 0.45469294436476654, 9.236151942309837e-07, 0.00012142774321173956, 1.1303153627484086e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361926284619701
# En la iteración 8 obtenemos:
# Suma de fracciones molares: 1.0010265420160478
# Temperatura de combustión inicial: 1560.4191675268164K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00047413662439751205, 0.4940294498232535, 0.002828271913825985, 0.8793125887614862, 0.40136514482924673, 1.63356993925311, 0.45471455086640317, 9.223094908913937e-07, 0.00012155614804394444, 1.128718690761419e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361938959887367
# En la iteración 9 obtenemos:
# Suma de fracciones molares: 1.0010296832100278
# Temperatura de combustión inicial: 1560.4093428523934K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004731826718820385, 0.4940305317523845, 0.0028235316691229946, 0.8793338656800104, 0.40135290579518373, 1.6335667713270845, 0.45474488135317503, 9.204540251798088e-07, 0.00012175255061252306, 1.1264497449484692e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361957022089945
# En la iteración 10 obtenemos:
# Suma de fracciones molares: 1.0010324307259366
# Temperatura de combustión inicial: 1560.3952472509156K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004722914369543791, 0.4940316151445807, 0.002819137719144894, 0.8793537290437132, 0.4013414273268479, 1.6335633779603946, 0.4547728372198464, 9.187205470219176e-07, 0.00012195874125053927, 1.1243299709296713e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361973969894024
# En la iteración 11 obtenemos:
# Suma de fracciones molares: 1.001035189718438
# Temperatura de combustión inicial: 1560.38201196286K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00047133514945199735, 0.4940328585058856, 0.0028144620751198355, 0.8793750305740845, 0.40132906901931015, 1.6335593706287723, 0.45480244490693905, 9.168605396920923e-07, 0.00012214785755486655, 1.1220554714243912e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361992258345459
# En la iteración 12 obtenemos:
# Suma de fracciones molares: 1.0010376012773232
# Temperatura de combustión inicial: 1560.3678401420352K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.000470438944262877, 0.49403410527190944, 0.0028101198148781517, 0.8793949864564314, 0.40131745170521477, 1.6335551820302674, 0.45482983498754564, 9.151173942294155e-07, 0.00012233747499499885, 1.1199238757962908e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362009457310685
# En la iteración 13 obtenemos:
# Suma de fracciones molares: 1.0010398493736679
# Temperatura de combustión inicial: 1560.3545347140537K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.000469546606030931, 0.49403542731532263, 0.002805835728802719, 0.8794148524173775, 0.40130585443343786, 1.6335506525404346, 0.45485677862104146, 9.133817701122236e-07, 0.0001225294405467908, 1.117801477603227e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362026651683238
# En la iteración 14 obtenemos:
# Suma de fracciones molares: 1.0010419479215542
# Temperatura de combustión inicial: 1560.3413173600347K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00046865640710834575, 0.49403682849976466, 0.0028016023422477903, 0.8794346697205168, 0.4012942581243665, 1.6335457929083277, 0.45488334279819614, 9.11650307014685e-07, 0.00012272183256357795, 1.1156841676896516e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362043873404192
# En la iteración 15 obtenemos:
# Suma de fracciones molares: 1.0010439055253912
# Temperatura de combustión inicial: 1560.3281837697007K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.000467768225928065, 0.4940383100580698, 0.002797419757865742, 0.8794544435120109, 0.40128266412302227, 1.6335406160376547, 0.4549095442081503, 9.099227684852988e-07, 0.00012291467053511887, 1.1135716569121753e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362061122265544
# En la iteración 16 obtenemos:
# Suma de fracciones molares: 1.0010456347193224
# Temperatura de combustión inicial: 1560.3151473382204K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00046693177423113354, 0.494039782756264, 0.0027935190842601695, 0.8794730689496669, 0.4012717256335462, 1.6335354520828775, 0.4549339525168202, 9.082958453231093e-07, 0.00012311318845467921, 1.1115821830707594e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3620774259352535
# En la iteración 17 obtenemos:
# Suma de fracciones molares: 1.00104737334745
# Temperatura de combustión inicial: 1560.302940224097K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004660318676165966, 0.49404145041026765, 0.002789363819147641, 0.8794931125802583, 0.4012599377442913, 1.6335296424578074, 0.4549599348537238, 9.065455004790867e-07, 0.00012329684276565824, 1.1094417837196588e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362095046075254
# En la iteración 18 obtenemos:
# Suma de fracciones molares: 1.0010488874702301
# Temperatura de combustión inicial: 1560.2899371229055K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00046518913078142114, 0.4940430927256458, 0.0027855126169699347, 0.8795118898513332, 0.4012488820775386, 1.6335238794201046, 0.4549840104220683, 9.049063525380793e-07, 0.00012348017062995234, 1.1074373608761997e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362111587976786
# En la iteración 19 obtenemos:
# Suma de fracciones molares: 1.0010502957796428
# Temperatura de combustión inicial: 1560.2778218217584K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004643494968214386, 0.49404480610188345, 0.002781714014717231, 0.8795306061657086, 0.4012378528182845, 1.6335178748387094, 0.45500776157641926, 9.032732397806208e-07, 0.00012366606810073952, 1.1054403181230104e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362128120242963
# En la iteración 20 obtenemos:
# Suma de fracciones molares: 1.0010516062348476
# Temperatura de combustión inicial: 1560.2658453866316K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00046351138761470634, 0.4940465930344648, 0.002777960575377159, 0.879549297944706, 0.40122683061801434, 1.6335116311766495, 0.455031242660437, 9.016430927130977e-07, 0.00012385265245069995, 1.103446901947084e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362144673601431
# En la iteración 21 obtenemos:
# Suma de fracciones molares: 1.0010528236062597
# Temperatura de combustión inicial: 1560.2539936841313K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00046267471312328985, 0.494048453044294, 0.0027742516204823904, 0.8795679683269796, 0.4012158154756729, 1.6335051564792888, 0.45505446478717937, 9.000157362090789e-07, 0.00012403990626446218, 1.1014568981960489e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362161248278212
# En la iteración 22 obtenemos:
# Suma de fracciones molares: 1.001053415034824
# Temperatura de combustión inicial: 1560.2422697217455K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00046224363960200714, 0.494049440672875, 0.0027723553454683763, 0.8795775922177952, 0.40121013598702904, 1.6335017436863895, 0.45506634718746725, 8.991772855262476e-07, 0.00012411925490524956, 1.1004316034928816e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362169812047512
# En la iteración 23 obtenemos:
# Suma de fracciones molares: 1.001054356917981
# Temperatura de combustión inicial: 1560.2362873497916K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00046152482703574994, 0.49405113304617027, 0.002769216100271753, 0.8795936475002688, 0.40120065934401233, 1.6334958661219514, 0.4550860363754171, 8.977791739346197e-07, 0.0001243106873647207, 1.0987219305940211e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362184102767598
# En la iteración 24 obtenemos:
# Suma de fracciones molares: 1.0010554345688145
# Temperatura de combustión inicial: 1560.2263294371573K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004606389881871345, 0.49405329280602744, 0.0027653845725755808, 0.8796134463899633, 0.4011889706387681, 1.6334884641205454, 0.4551100990339785, 8.960561913092428e-07, 0.00012450197027512048, 1.0966149909781467e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362201785777157
# En la iteración 25 obtenemos:
# Suma de fracciones molares: 1.0010563646763175
# Temperatura de combustión inicial: 1560.2142302770792K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004598054998405325, 0.494055401327023, 0.0027618177979388085, 0.8796320896933353, 0.40117796338318523, 1.6334812430616876, 0.45513253823637695, 8.944350319506373e-07, 0.00012468991826245917, 1.0946325653715361e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362218459425021
# En la iteración 26 obtenemos:
# Suma de fracciones molares: 1.0010572176660442
# Temperatura de combustión inicial: 1560.2029434369795K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00045897457333025096, 0.49405757572326875, 0.002758298287931182, 0.87965069047107, 0.40116698168509285, 1.633473830980336, 0.45515472236195065, 8.928188554390541e-07, 0.00012488037711636817, 1.0926562330113908e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362235124607403
# En la iteración 27 obtenemos:
# Suma de fracciones molares: 1.001057998415657
# Temperatura de combustión inicial: 1560.1918057798093K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004581448583404399, 0.4940598180873049, 0.002754819641783936, 0.8796692795111409, 0.40115600831825776, 1.6334662265870536, 0.45517669476658973, 8.912050353704338e-07, 0.00012507165586652573, 1.0906827822142733e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362251808297775
# En la iteración 28 obtenemos:
# Suma de fracciones molares: 1.001058710076187
# Temperatura de combustión inicial: 1560.1808022818732K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004573162850676265, 0.4940621273181839, 0.0027513809165698156, 0.8796878590753332, 0.4011450427797976, 1.6334584357836415, 0.455198464042003, 8.895934359749679e-07, 0.00012526372972198317, 1.0887120469548361e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362268510867471
# En la iteración 29 obtenemos:
# Suma de fracciones molares: 1.0010593555811695
# Temperatura de combustión inicial: 1560.1699319439056K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00045648881439568876, 0.49406450218024656, 0.002747981294488684, 0.8797064305792568, 0.4011340849654979, 1.633450464438912, 0.45522003757122076, 8.879839811706478e-07, 0.0001254566094170813, 1.0867439341966239e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362285232004633
# En la iteración 30 obtenemos:
# Suma de fracciones molares: 1.0010594316729848
# Temperatura de combustión inicial: 1560.1591937796031K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00045637160538291856, 0.49406484365563913, 0.0027475022989215093, 0.8797090624722206, 0.4011325323363043, 1.6334493424974035, 0.45522308130209843, 8.877560061920654e-07, 0.00012542439693701192, 1.0864651562758665e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362287611405237
# En la iteración 31 obtenemos:
# Suma de fracciones molares: 1.0010598786981055
# Temperatura de combustión inicial: 1560.1577142079216K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00045574862104897073, 0.49406668380740393, 0.002744969018681597, 0.8797230578910551, 0.40112427737288897, 1.633443181169944, 0.4552391991285405, 8.86544283331838e-07, 0.00012562191965235142, 1.0849834077893152e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3623002249886325
# En la iteración 32 obtenemos:
# Suma de fracciones molares: 1.001060349028734
# Temperatura de combustión inicial: 1560.1496932274802K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004550212914889049, 0.4940688799292698, 0.0027420354378184454, 0.8797394102126763, 0.40111463534206215, 1.633435861849884, 0.45525790490756957, 8.851296059366494e-07, 0.00012581440212381572, 1.0832534774907122e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3623149804752686
# En la iteración 33 obtenemos:
# Suma de fracciones molares: 1.0010608294700472
# Temperatura de combustión inicial: 1560.1404270148505K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00045418851870652284, 0.49407145567761945, 0.0027387073685861785, 0.8797581501927413, 0.40110358945847585, 1.6334273554975998, 0.4552791796292412, 8.835098383715068e-07, 0.00012599870854344272, 1.0812727538309114e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362331926522844
# En la iteración 34 obtenemos:
# Suma de fracciones molares: 1.0010612370541392
# Temperatura de combustión inicial: 1560.1299642103195K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00045338648347670833, 0.49407399819589726, 0.0027355332208017784, 0.8797762164907162, 0.4010929455383001, 1.633418973253142, 0.4552995281523837, 8.819498562505262e-07, 0.00012618845214823075, 1.0793651384653573e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362348274141657
# En la iteración 35 obtenemos:
# Suma de fracciones molares: 1.0010615930995155
# Temperatura de combustión inicial: 1560.1199774624495K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004525859247118136, 0.4940765951817455, 0.0027323946535172095, 0.8797942674525814, 0.4010823157860263, 1.6334104483906693, 0.45531970638216235, 8.803927458972577e-07, 0.00012637995347487615, 1.0774610348248044e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362364625779441
# En la iteración 36 obtenemos:
# Suma de fracciones molares: 1.0010618998427239
# Temperatura de combustión inicial: 1560.110114349677K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004517862215449862, 0.49407924724834024, 0.002729288519599405, 0.8798123173904795, 0.4010716920532741, 1.6334017804436927, 0.4553397349061709, 8.788372997074054e-07, 0.00012657228050136392, 1.0755589661971275e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362380993865512
# En la iteración 37 obtenemos:
# Suma de fracciones molares: 1.0010621591446562
# Temperatura de combustión inicial: 1560.1003665900446K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004509873376450382, 0.4940819531861767, 0.0027262140016970256, 0.8798303674272233, 0.4010610739214217, 1.6333929734206958, 0.45535961924337953, 8.772834470157399e-07, 0.000126765420612357, 1.0736588461697477e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.36239737844005
# En la iteración 38 obtenemos:
# Suma de fracciones molares: 1.0010623727731915
# Temperatura de combustión inicial: 1560.0907318197599K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00045018924811297877, 0.4940847117541239, 0.0027231703348164367, 0.8798484183798753, 0.4010504611148563, 1.6333840312805803, 0.4553793644332011, 8.757311393929905e-07, 0.00012695937669212644, 1.0717606155212059e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.36241377930493
# En la iteración 39 obtenemos:
# Suma de fracciones molares: 1.0010625424127289
# Temperatura de combustión inicial: 1560.0812077153344K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004493919292907873, 0.49408752171971004, 0.0027201567595053853, 0.8798664710342401, 0.401039853342763, 1.633374957831363, 0.45539897535211665, 8.741803308236117e-07, 0.00012715415145361924, 1.0698642179816502e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362430196281078
# En la iteración 40 obtenemos:
# Suma de fracciones molares: 1.0010626696689722
# Temperatura de combustión inicial: 1560.0717918766793K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004485953584934703, 0.4940903818625746, 0.0027171725211444825, 0.8798845261575773, 0.40102925029298386, 1.6333657567335356, 0.4554184567316041, 8.726309771846239e-07, 0.0001273497471384466, 1.0679695995955424e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362446629217609
# En la iteración 41 obtenemos:
# Suma de fracciones molares: 1.0010627560746654
# Temperatura de combustión inicial: 1560.0624818337071K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004477995146643561, 0.49409329096016585, 0.0027142168913619554, 0.8799025843913268, 0.401018651702237, 1.6333564315652347, 0.45543781304340736, 8.710830375201806e-07, 0.00012754616534875344, 1.0660767102802559e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362463077887926
# En la iteración 42 obtenemos:
# Suma de fracciones molares: 1.0010628030946807
# Temperatura de combustión inicial: 1560.0532751216622K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004470043773838141, 0.49409624781229994, 0.0027112891425308126, 0.8799206463953296, 0.401008057272076, 1.6333469857534935, 0.45545704866278863, 8.695364721134998e-07, 0.00012774340755879873, 1.0641855014683473e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362479542120637
# En la iteración 43 obtenemos:
# Suma de fracciones molares: 1.0010628121291474
# Temperatura de combustión inicial: 1560.044169222016K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00044620992685116795, 0.49409925124304155, 0.002708388548872713, 0.8799387128591775, 0.4009974666637497, 1.6333374225723527, 0.45547616788434525, 8.679912424516826e-07, 0.0001279414749889164, 1.0622959260645354e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362496021808878
# En la iteración 44 obtenemos:
# Suma de fracciones molares: 1.0010627912180263
# Temperatura de combustión inicial: 1560.0351615616182K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00044548808783157406, 0.49410202203039305, 0.0027057740385154237, 0.8799551457305049, 0.40098783939176746, 1.6333286222663255, 0.4554934557585088, 8.665872443192651e-07, 0.00012813724645995456, 1.060579054842367e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362511018896031
# En la iteración 45 obtenemos:
# Suma de fracciones molares: 1.0010627288876839
# Temperatura de combustión inicial: 1560.0270466200013K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004446647611358343, 0.49410522895231634, 0.002702815287975616, 0.8799739092346645, 0.40097685288012025, 1.6333184968133363, 0.45551308051282535, 8.649858496705822e-07, 0.00012833060927049485, 1.0586207984001563e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.36252816529498
# En la iteración 46 obtenemos:
# Suma de fracciones molares: 1.0010627100708211
# Temperatura de combustión inicial: 1560.017906832473K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004445731100552584, 0.4941055888651825, 0.0027024873887666278, 0.8799759992568505, 0.40097562954461563, 1.6333173714069091, 0.45551525937708226, 8.648075856221314e-07, 0.00012830415870926642, 1.0584028092108078e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362530079206605
# Archivo generado exitosamente en:
#  0.144 9.28 1560.02 33.9132 21.6137 384.6708 1.3248 891.62 0.0004445731100552584 0.4941055888651825 0.0027024873887666278 0.8799759992568505 0.40097562954461563 1.6333173714069091 0.45551525937708226 8.648075856221314e-07 0.00012830415870926642 1.0584028092108078e-07 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.0009945317880253
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.000409323041256503, 0.4937961686748131, 0.0027900946810621484, 0.8788305306274811, 0.4014556896653391, 1.6351122345621705, 0.4540740042944424, 7.331576886800531e-06, 0.00011996314041119536, 1.298904943697525e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362257066933753
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.0009098021305398
# Temperatura de combustión inicial: 1560.7123348470377K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004207291979240907, 0.4938543883012528, 0.002804589393792037, 0.8789364073363876, 0.40144087651766003, 1.6341259689501786, 0.4542051656480356, 7.244308997280622e-07, 0.00012150322835731615, 1.264740176752386e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3619419754759265
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.0009522327370621
# Temperatura de combustión inicial: 1560.2253459340259K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004197645673445953, 0.49389647341562715, 0.002808507959819247, 0.8790448407022651, 0.40140927823714734, 1.6341322281805557, 0.4543368580227171, 7.121213581058031e-07, 0.00012205244326055558, 1.253912821197122e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362017185577643
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.0009711878787404
# Temperatura de combustión inicial: 1560.3377672536828K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004172247056421293, 0.4939173819720239, 0.0028065765662451604, 0.8791171029687017, 0.40138119896754626, 1.6341179718183771, 0.4544230172695739, 7.078131426195549e-07, 0.00012314073584109136, 1.2463318429613554e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3620680599242405
# En la iteración 5 obtenemos:
# Suma de fracciones molares: 1.0009826901153946
# Temperatura de combustión inicial: 1560.365064788609K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004152278969214598, 0.4939309756762886, 0.002803484534289644, 0.879172647402438, 0.40135700409353386, 1.6341033405616154, 0.4544881812501788, 7.044260754240807e-07, 0.0001238172054556746, 1.2403717690574558e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362108905879891
# En la iteración 6 obtenemos:
# Suma de fracciones molares: 1.0009837703835998
# Temperatura de combustión inicial: 1560.3721286550283K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004150158700239828, 0.49393230596447546, 0.0028030930567494567, 0.8791784939492552, 0.40135434629081834, 1.6341016346600759, 0.45449498110509945, 7.04066426880097e-07, 0.00012390227548574046, 1.239738911255155e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362113283454133
# Archivo generado exitosamente en:
#  0.5168 11.91 1560.37 33.9192 21.6219 384.5237 1.3247 891.53 0.0004150158700239828 0.49393230596447546 0.0028030930567494567 0.8791784939492552 0.40135434629081834 1.6341016346600759 0.45449498110509945 7.04066426880097e-07 0.00012390227548574046 1.239738911255155e-07 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.0015222992111845
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003306263194388103, 0.49476415111042793, 0.003108802588670607, 0.8805753747665144, 0.4010933428147851, 1.6343236244701846, 0.45552929664077824, 5.555967517498201e-06, 0.0001286068680295784, 2.4729196203706235e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.36321728414566
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.0012091229716265
# Temperatura de combustión inicial: 1563.080301603835K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003306890031936933, 0.4947826650916237, 0.0031093922754161173, 0.8805814369560877, 0.40110724428992695, 1.632033579974963, 0.4555454330666775, 5.846910399986566e-07, 0.00012952340710375144, 2.4719695632820113e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362345960864265
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.0011047002258509
# Temperatura de combustión inicial: 1561.5643088058637K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003219712287794423, 0.4943631292509374, 0.0030274210351461574, 0.8806979945501429, 0.40072990993776286, 1.6321977272262695, 0.4560325041632224, 5.647951033888519e-07, 0.00012934336821144148, 2.4070634829812986e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.36268113489118
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.001115443514306
# Temperatura de combustión inicial: 1559.7568497054158K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003139742808630429, 0.49426704810511013, 0.002952227561731353, 0.8809060216513026, 0.4005362844871279, 1.6323842528925498, 0.4563880483850982, 5.437320050255202e-07, 0.00012837474427194082, 2.347523288800001e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3630101080873755
# En la iteración 5 obtenemos:
# Suma de fracciones molares: 1.0011087332182116
# Temperatura de combustión inicial: 1559.3164710324509K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00031200520880477357, 0.4942623798397113, 0.002933712827288904, 0.8809628655972893, 0.4004960904752886, 1.6323523738365284, 0.45645740345668473, 5.325489093912191e-07, 0.00012963562498658323, 2.332860340861569e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363069542708726
# En la iteración 6 obtenemos:
# Suma de fracciones molares: 1.0011052190473781
# Temperatura de combustión inicial: 1559.2301715006788K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003106797003601382, 0.49426165331775485, 0.0029212493743375964, 0.8810019776856871, 0.400470093297892, 1.6323335517194977, 0.4565033170360474, 5.302868774378366e-07, 0.00012990796719823257, 2.322992005662458e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.36311079056402
# En la iteración 7 obtenemos:
# Suma de fracciones molares: 1.0011044342905948
# Temperatura de combustión inicial: 1559.1838141108499K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00031036777518501257, 0.4942617195785831, 0.002918316413208423, 0.8810112644069384, 0.40046407509124093, 1.632329059990916, 0.45651404027565595, 5.297545649383921e-07, 0.00012988792904120383, 2.3206697404233044e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363120504622729
# En la iteración 8 obtenemos:
# Suma de fracciones molares: 1.0011013002859268
# Temperatura de combustión inicial: 1559.1738361077144K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003089822902572482, 0.4942630564385439, 0.0029052890150942715, 0.881052874772683, 0.4004377588088164, 1.6323083998418446, 0.45656127398213514, 5.27390180773043e-07, 0.0001305246545026511, 2.3103548837086383e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363163557124601
# En la iteración 9 obtenemos:
# Suma de fracciones molares: 1.0010982161584099
# Temperatura de combustión inicial: 1559.1329543374602K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00030749258147996973, 0.4942660795926897, 0.0028912816239441775, 0.8810981620533553, 0.40041005756970205, 1.6322857505808739, 0.4566114003621607, 5.248479345360794e-07, 0.00013097457842714107, 2.2992640863450005e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363209999159596
# En la iteración 10 obtenemos:
# Suma de fracciones molares: 1.0010954241316425
# Temperatura de combustión inicial: 1559.0950396502997K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.000306040035731733, 0.49427039616076773, 0.002877623668262313, 0.8811427902059299, 0.4003835165380431, 1.6322629217908586, 0.4566596467514815, 5.223691084602752e-07, 0.0001314709871353412, 2.288449965625017e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363255336303914
# En la iteración 11 obtenemos:
# Suma de fracciones molares: 1.001092803391924
# Temperatura de combustión inicial: 1559.0629052614308K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003046016661470561, 0.49427581308336, 0.002864137688734473, 0.8811873754673357, 0.4003575842895448, 1.632239664418325, 0.45670684555677576, 5.199144745615016e-07, 0.00013198510298988614, 2.27774138563879e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363300320674685
# En la iteración 12 obtenemos:
# Suma de fracciones molares: 1.0010903754158917
# Temperatura de combustión inicial: 1559.0350629408981K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003031744891877482, 0.49428214602043224, 0.002851212508248821, 0.8812319457120165, 0.40033210836566985, 1.632215954380047, 0.45675314272689904, 5.174789413152585e-07, 0.0001325134456342115, 2.2671161341136868e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363345053720607
# En la iteración 13 obtenemos:
# Suma de fracciones molares: 1.0010881639860216
# Temperatura de combustión inicial: 1559.0106766842262K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003018059747820927, 0.4942889718682778, 0.0028392993705015804, 0.8812749511845854, 0.40030784447069845, 1.632192619041374, 0.4567970653158655, 5.151435180089901e-07, 0.0001330324469114969, 2.2569276219737016e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363388045757359
# En la iteración 14 obtenemos:
# Suma de fracciones molares: 1.0010860265416364
# Temperatura de combustión inicial: 1558.9897358012702K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003004449847560018, 0.49429637472778865, 0.002827854477622341, 0.8813179455006441, 0.400283817317774, 1.6321688511689862, 0.4568403192039613, 5.128209353504551e-07, 0.00013356432702215978, 2.246795128412859e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363430905321665
# En la iteración 15 obtenemos:
# Suma de fracciones molares: 1.0010839572685826
# Temperatura de combustión inicial: 1558.9708217497648K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0002991139803820541, 0.4943041206253037, 0.002817002587349746, 0.8813601863102225, 0.40026037739692316, 1.6321450784779226, 0.4568822360451031, 5.105495243789546e-07, 0.00013409440080460705, 2.236885876331699e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363472924649458
# En la iteración 16 obtenemos:
# Suma de fracciones molares: 1.0010818895813907
# Temperatura de combustión inicial: 1558.9538268479664K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00029778771462112507, 0.49431226658775046, 0.00280648560640621, 0.8814024493346906, 0.40023704529102894, 1.6321208878902151, 0.4569236541234826, 5.082862000357258e-07, 0.00013463351306199585, 2.2270119029557316e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363514899409661
# En la iteración 17 obtenemos:
# Suma de fracciones molares: 1.0010799163021322
# Temperatura de combustión inicial: 1558.938097942451K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00029653667489860697, 0.49432029117073545, 0.0027968082478543664, 0.8814424607788265, 0.4002150361465195, 1.6320976234748774, 0.456962426668461, 5.061512518664103e-07, 0.00013515197962597064, 2.2176979831695712e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363554589833225
# En la iteración 18 obtenemos:
# Suma de fracciones molares: 1.001078058021532
# Temperatura de combustión inicial: 1558.9241696634756K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0002953719887952441, 0.4943280231676588, 0.0027879907518673524, 0.881479829672793, 0.4001945302032851, 1.6320755910224498, 0.45699828454138997, 5.041636695223447e-07, 0.00013568303238813308, 2.2090269611808034e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363591625779706
# En la iteración 19 obtenemos:
# Suma de fracciones molares: 1.0010760904334952
# Temperatura de combustión inicial: 1558.9118496394706K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0002941723561453428, 0.49433621886115475, 0.00277908413215027, 0.8815184328868446, 0.40017338007054587, 1.6320525759993436, 0.45703499628084227, 5.021164495311178e-07, 0.00013614945607636484, 2.2000957641349183e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363629873897894
# En la iteración 20 obtenemos:
# Suma de fracciones molares: 1.0010760917023178
# Temperatura de combustión inicial: 1558.899762887013K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0002941723292285281, 0.4943362190476529, 0.0027790839343085623, 0.881518433754346, 0.4001733795955815, 1.6320525754771764, 0.45703499710208456, 5.021164035965218e-07, 0.00013615519899717808, 2.2000955637407594e-08, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.363629874756524
# Archivo generado exitosamente en:
#  0.9127 14.64 1558.9 33.8991 21.6054 384.8175 1.325 891.53 0.0002941723292285281 0.4943362190476529 0.0027790839343085623 0.881518433754346 0.4001733795955815 1.6320525754771764 0.45703499710208456 5.021164035965218e-07 0.00013615519899717808 2.2000955637407594e-08 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.000898932075504
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00038064633247459733, 0.4937054702587754, 0.002752586344491285, 0.8787301903666448, 0.4014422473299684, 1.6349973170828762, 0.4539690425641271, 4.923768525301815e-06, 0.0001197798385503151, 1.374394595767943e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362181036972603
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.0009287079178226
# Temperatura de combustión inicial: 1560.270989434447K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00039280995494416306, 0.4938362092007591, 0.002791676146114551, 0.878955639652011, 0.4014094581245267, 1.6344269232711408, 0.45421057385138386, 4.6705810171383013e-07, 0.00012512267491976718, 1.349920744282262e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362097900167773
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.0009663183212882
# Temperatura de combustión inicial: 1560.3066205874165K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003877405938811748, 0.4938893890705379, 0.0027953065589605033, 0.8791134230000459, 0.4013515064538265, 1.6343782754388163, 0.45437766387066436, 4.610318292334428e-07, 0.00012674122433800332, 1.3325124073679707e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362205361631973
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.000984696379085
# Temperatura de combustión inicial: 1560.3873649264806K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003830293559062925, 0.4939228707703705, 0.0027898018416719016, 0.8792536117319188, 0.40128640764978585, 1.6343176281055392, 0.4545223270198189, 4.554312804850263e-07, 0.000128687487375531, 1.3163338758072674e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362309400855584
# En la iteración 5 obtenemos:
# Suma de fracciones molares: 1.0009943759658202
# Temperatura de combustión inicial: 1560.384265818034K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00037815998251443557, 0.49395052641748766, 0.002780052519441346, 0.8793957833336656, 0.40121333718352986, 1.6342445595280184, 0.45466451817463704, 4.496427460911512e-07, 0.0001301981123385758, 1.2996123025135792e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362419829524312
# En la iteración 6 obtenemos:
# Suma de fracciones molares: 1.0009943777292947
# Temperatura de combustión inicial: 1560.3440002757654K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003781599141922976, 0.4939505267796747, 0.00278005236634596, 0.879395785319341, 0.4012133361313678, 1.6342445584417598, 0.45466452012728353, 4.4964266487227275e-07, 0.00013020543281651713, 1.299612067893322e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.362419831090783
# Archivo generado exitosamente en:
#  1.3127 17.74 1560.34 33.9191 21.6198 384.5622 1.3247 891.57 0.0003781599141922976 0.4939505267796747 0.00278005236634596 0.879395785319341 0.4012133361313678 1.6342445584417598 0.45466452012728353 4.4964266487227275e-07 0.00013020543281651713 1.299612067893322e-07 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.0009436265257567
# Temperatura de combustión inicial: 1659K
# ...
# Suma de fracciones molares: 1.011703734862302
# Suma de fracciones molares: 1.0116830818847462
# Suma de fracciones molares: 1.0116649539847826
# Suma de fracciones molares: 1.0116443954997156
# Suma de fracciones molares: 1.011637012152176
# Suma de fracciones molares: 1.0116214390112883
# Suma de fracciones molares: 1.0116009900488783
# Suma de fracciones molares: 1.011580596088682
# Suma de fracciones molares: 1.0115602530036298
# Suma de fracciones molares: 1.0115399604816357
# Suma de fracciones molares: 1.0115326711306085
# Suma de fracciones molares: 1.0115132543939522
# Suma de fracciones molares: 1.0115124463633418
# Suma de fracciones molares: 1.0114925869945368
# Suma de fracciones molares: 1.0114732687721322
# Suma de fracciones molares: 1.0114531866309024
# Suma de fracciones molares: 1.011450784305057
# Suma de fracciones molares: 1.011444371323889
# Suma de fracciones molares: 1.0114435700533146
# Suma de fracciones molares: 1.0114235603370043
# Suma de fracciones molares: 1.011403603038068
# Suma de fracciones molares: 1.0113844928144387
# Suma de fracciones molares: 1.0113646260770777
# Suma de fracciones molares: 1.0113448109285015
# Suma de fracciones molares: 1.0113376927698878
# Suma de fracciones molares: 1.0113181295669498
# Suma de fracciones molares: 1.011305517091334
# Suma de fracciones molares: 1.0113047292099093
# Suma de fracciones molares: 1.011285053215703
# Suma de fracciones molares: 1.0112819137716276
# Suma de fracciones molares: 1.011267783714265
# Suma de fracciones molares: 1.011260727724511
# Suma de fracciones molares: 1.011255243880712
# Suma de fracciones molares: 1.0112449109903012
# Suma de fracciones molares: 1.0112296550934832
# Suma de fracciones molares: 1.0112144283199462
# Suma de fracciones molares: 1.0111992305342892
# Suma de fracciones molares: 1.011184061606411
# Suma de fracciones molares: 1.0111720732474987
# Suma de fracciones molares: 1.011156955686191
# Suma de fracciones molares: 1.0111418666022205
# Suma de fracciones molares: 1.0111268058801202
# Suma de fracciones molares: 1.0111117733839263
# Suma de fracciones molares: 1.0110967689887205
# Suma de fracciones molares: 1.0110817925653743
# Suma de fracciones molares: 1.0110687097284203
# Suma de fracciones molares: 1.0110606195386416
# Suma de fracciones molares: 1.0110593791829896
# Suma de fracciones molares: 1.0110444392156808
# Suma de fracciones molares: 1.0110357561918055
# Suma de fracciones molares: 1.0110208927248245
# Suma de fracciones molares: 1.0110153259791796
# Suma de fracciones molares: 1.0110097630723605
# Suma de fracciones molares: 1.0109967950859364
# Suma de fracciones molares: 1.0109820035147692
# Suma de fracciones molares: 1.0109746208237298
# Suma de fracciones molares: 1.0109721603752815
# Suma de fracciones molares: 1.0109574133820132
# Suma de fracciones molares: 1.0109445317663
# Suma de fracciones molares: 1.0109439188667384
# Suma de fracciones molares: 1.0109292231748896
# Suma de fracciones molares: 1.0109212741227567
# Suma de fracciones molares: 1.0109182188685581
# Suma de fracciones molares: 1.0109127391136292
# Suma de fracciones molares: 1.0108980997235035
# Suma de fracciones molares: 1.0108895722535611
# Suma de fracciones molares: 1.0108822701150388
# Suma de fracciones molares: 1.0108676854915761
# Suma de fracciones molares: 1.0108567641648294
# Suma de fracciones molares: 1.0108440411119228
# Suma de fracciones molares: 1.0108373845896506
# Suma de fracciones molares: 1.0108271079042073
# Suma de fracciones molares: 1.010812621681399
# Suma de fracciones molares: 1.0107981611487387
# Suma de fracciones molares: 1.0107975591833682
# Suma de fracciones molares: 1.0107843271403334
# Suma de fracciones molares: 1.0107699165888593
# Suma de fracciones molares: 1.0107651187134563
# Suma de fracciones molares: 1.0107591253243324
# Suma de fracciones molares: 1.0107447590804877
# Suma de fracciones molares: 1.0107304180113459
# Suma de fracciones molares: 1.0107161020039257
# Suma de fracciones molares: 1.0107071671838548
# Suma de fracciones molares: 1.0107018109572559
# Suma de fracciones molares: 1.0106940803556386
# Suma de fracciones molares: 1.0106875447609165
# Suma de fracciones molares: 1.0106756751741945
# Suma de fracciones molares: 1.0106650071918362
# Suma de fracciones molares: 1.010664414933148
# Suma de fracciones molares: 1.0106502134785091
# Suma de fracciones molares: 1.0106466669433456
# Suma de fracciones molares: 1.0106443034374175
# Suma de fracciones molares: 1.0106301366392745
# Suma de fracciones molares: 1.0106195275077743
# Suma de fracciones molares: 1.010614228061971
# Suma de fracciones molares: 1.0106024636982072
# Suma de fracciones molares: 1.010588368581609
# Suma de fracciones molares: 1.0105825027142206
# Suma de fracciones molares: 1.0105726110010589
# Suma de fracciones molares: 1.0105650007046272
# Suma de fracciones molares: 1.010562660486702
# Suma de fracciones molares: 1.0105486330669207
# Suma de fracciones molares: 1.0105392946586549
# Suma de fracciones molares: 1.0105266240088644
# Suma de fracciones molares: 1.010523758432845
# Suma de fracciones molares: 1.010516434613035
# Suma de fracciones molares: 1.010510075178076
# Suma de fracciones molares: 1.0105068967242157
# Suma de fracciones molares: 1.0105049903260683
# Suma de fracciones molares: 1.0104976855871017
# Suma de fracciones molares: 1.0104976871394458
# Suma de fracciones molares: 1.0104903899463211
# Suma de fracciones molares: 1.010488172652161
# Suma de fracciones molares: 1.01048088495279
# Suma de fracciones molares: 1.0104739241790825
# Suma de fracciones molares: 1.0104720264916431
# Suma de fracciones molares: 1.0104672844574054
# Suma de fracciones molares: 1.0104600178319423
# Suma de fracciones molares: 1.010453077170418
# Suma de fracciones molares: 1.0104502390411583
# Suma de fracciones molares: 1.0104429895456144
# Suma de fracciones molares: 1.0104358563863092
# Suma de fracciones molares: 1.0104308235917356
# Suma de fracciones molares: 1.010423593521169
# Suma de fracciones molares: 1.0104201406559778
# Suma de fracciones molares: 1.0104129212457258
# Suma de fracciones molares: 1.0104129228055443
# Suma de fracciones molares: 1.0104088464704455
# Suma de fracciones molares: 1.0104019530553514
# Suma de fracciones molares: 1.0103947517486607
# Suma de fracciones molares: 1.010391625351093
# Suma de fracciones molares: 1.0103844342906452
# Suma de fracciones molares: 1.01038256163628
# Suma de fracciones molares: 1.0103772536114397
# Suma de fracciones molares: 1.0103769414956378
# Suma de fracciones molares: 1.0103697649685748
# Suma de fracciones molares: 1.0103685195677106
# Suma de fracciones molares: 1.0103641564198709
# Suma de fracciones molares: 1.010362910287508
# Suma de fracciones molares: 1.0103557476064797
# Suma de fracciones molares: 1.0103535712330267
# Suma de fracciones molares: 1.0103492170517026
# Suma de fracciones molares: 1.0103420678441248
# Suma de fracciones molares: 1.0103414483373194
# Suma de fracciones molares: 1.010334306756982
# Suma de fracciones molares: 1.0103274854284667
# Suma de fracciones molares: 1.0103246960330008
# Suma de fracciones molares: 1.0103175708589047
# Suma de fracciones molares: 1.0103144775086725
# Suma de fracciones molares: 1.010310146649922
# Suma de fracciones molares: 1.010306127443096
# Suma de fracciones molares: 1.0102990203880464
# Suma de fracciones molares: 1.0102922320068548
# Suma de fracciones molares: 1.0102872977400674
# Suma de fracciones molares: 1.0102802089931724
# Suma de fracciones molares: 1.0102734380766736
# Suma de fracciones molares: 1.010273130380549
# Suma de fracciones molares: 1.0102660553526686
# Suma de fracciones molares: 1.010262062037452
# Suma de fracciones molares: 1.010258683347222
# Suma de fracciones molares: 1.0102571480939946
# Suma de fracciones molares: 1.0102500884989616
# Suma de fracciones molares: 1.010243345414838
# Suma de fracciones molares: 1.0102399753513098
# Suma de fracciones molares: 1.010232932284671
# Suma de fracciones molares: 1.0102262276461142
# Suma de fracciones molares: 1.0102246991817632
# Suma de fracciones molares: 1.0102176707661616
# Suma de fracciones molares: 1.0102130933736846
# Suma de fracciones molares: 1.0102103472891493
# Suma de fracciones molares: 1.010203332597924
# Suma de fracciones molares: 1.0101981550005126
# Suma de fracciones molares: 1.0101960810044897
# Suma de fracciones molares: 1.0101890799153745
# Suma de fracciones molares: 1.0101884732798485
# Suma de fracciones molares: 1.0101869526570861
# Suma de fracciones molares: 1.0101799602516874
# Suma de fracciones molares: 1.0101784430896257
# Suma de fracciones molares: 1.0101772282232768
# Suma de fracciones molares: 1.0101702601746425
# Suma de fracciones molares: 1.010166015445876
# Suma de fracciones molares: 1.0101654090121657
# Suma de fracciones molares: 1.0101623775948212
# Suma de fracciones molares: 1.0101560044711033
# Suma de fracciones molares: 1.0101496639029128
# Suma de fracciones molares: 1.0101491128085407
# Suma de fracciones molares: 1.0101427782237387
# Suma de fracciones molares: 1.0101364491274747
# Suma de fracciones molares: 1.0101301255093866
# Suma de fracciones molares: 1.0101239332700476
# Suma de fracciones molares: 1.0101179406254068
# Suma de fracciones molares: 1.0101122159094742
# Suma de fracciones molares: 1.0101109151388705
# Suma de fracciones molares: 1.0101055826051968
# Suma de fracciones molares: 1.0101003357603089
# Suma de fracciones molares: 1.0100950927750132
# Suma de fracciones molares: 1.0100922345876464
# Suma de fracciones molares: 1.0100867595242398
# Suma de fracciones molares: 1.010085331956614
# Suma de fracciones molares: 1.010082715489068
# Suma de fracciones molares: 1.0100774854314605
# Suma de fracciones molares: 1.0100753469659396
# Suma de fracciones molares: 1.0100746342865592
# Suma de fracciones molares: 1.010073209141243
# Suma de fracciones molares: 1.0100720217375998
# Suma de fracciones molares: 1.0100667995017882
# Suma de fracciones molares: 1.0100615810816194
# Suma de fracciones molares: 1.0100563664683821
# Suma de fracciones molares: 1.0100554187650377
# Suma de fracciones molares: 1.0100547080708147
# Suma de fracciones molares: 1.0100494984659243
# Suma de fracciones molares: 1.0100447657503522
# Suma de fracciones molares: 1.0100433465452339
# Suma de fracciones molares: 1.0100407454011702
# Suma de fracciones molares: 1.0100386178938963
# Suma de fracciones molares: 1.010036727308095
# Suma de fracciones molares: 1.010032711468414
# Suma de fracciones molares: 1.0100279898329299
# Suma de fracciones molares: 1.0100270458784064
# Suma de fracciones molares: 1.0100256301799624
# Suma de fracciones molares: 1.0100239788859173
# Suma de fracciones molares: 1.0100237430173689
# Suma de fracciones molares: 1.0100223279714273
# Suma de fracciones molares: 1.0100180985383937
# Suma de fracciones molares: 1.0100129154768513
# Suma de fracciones molares: 1.010012444475174
# Suma de fracciones molares: 1.0100072654957926
# Suma de fracciones molares: 1.0100039717271831
# Suma de fracciones molares: 1.0100011496984298
# Suma de fracciones molares: 1.0099983287791794
# Temperatura de combustión inicial: 1559.5299560220462K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00020738301955776174, 0.501389050631351, 0.001587290364121616, 0.8571072813939623, 0.3968608453406065, 1.6302623042832407, 0.4501272124650297, 4.672416513610678e-06, 0.00017198599827988905, 1.7664334379702206e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.294777604136394
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.0099922613017014
# Temperatura de combustión inicial: 1571.750457370307K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0002072927850828103, 0.5013880945274731, 0.0015865997176890442, 0.8571073513799854, 0.39686576262577905, 1.6302676508852738, 0.450128189043703, 6.314681111965714e-06, 0.000172236852625143, 2.0549727797154798e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.294814786506813
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.009989713753987
# Temperatura de combustión inicial: 1571.7551917273722K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00020725733741903526, 0.501387717661309, 0.001586328404450128, 0.8571073816889364, 0.39686769493393365, 1.6302697464300757, 0.4501285733264927, 6.313601299870864e-06, 0.0001722871575489172, 2.0546215442800886e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.294829389876543
# En la iteración 5 obtenemos:
# Suma de fracciones molares: 1.0099888656824492
# Temperatura de combustión inicial: 1571.7576625589763K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00020724552338122237, 0.5013875918988243, 0.001586237980864415, 0.8571073921423779, 0.39686833901059776, 1.6302704446143115, 0.45012870148062695, 6.313241418862916e-06, 0.00017230770782471007, 2.0545044841335786e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.2948342566327895
# Archivo generado exitosamente en:
#  2.16 1.24 1571.76 34.1753 21.5528 385.7572 1.3215 895.12 0.00020724552338122237 0.5013875918988243 0.001586237980864415 0.8571073921423779 0.39686833901059776 1.6302704446143115 0.45012870148062695 6.313241418862916e-06 0.00017230770782471007 2.0545044841335786e-07 1e-10 0.5
# En la iteración 1 obtenemos:
# Suma de fracciones molares: 1.0007756578582525
# Temperatura de combustión inicial: 1659K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003600657940146247, 0.4936408320317225, 0.002725668620744906, 0.8786600012642589, 0.40143172266060767, 1.6343915953015455, 0.45389515045442885, 8.072034602871264e-05, 0.00012968930053737897, 1.3822885263916453e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.3619322171013835
# En la iteración 2 obtenemos:
# Suma de fracciones molares: 1.0005345370203227
# Temperatura de combustión inicial: 1559.514975166331K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003600525048516974, 0.49364079102869973, 0.0027256516855024555, 0.878659957546894, 0.40143171558303997, 1.6329120808934636, 0.45389510393865157, 1.4736548304584455e-05, 6.893521393749401e-05, 1.3280542798635456e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361377839933713
# En la iteración 3 obtenemos:
# Suma de fracciones molares: 1.00046189255981
# Temperatura de combustión inicial: 1558.5583103670813K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0003557276450444657, 0.4936334851235282, 0.0027225120056609984, 0.878653913600127, 0.4014288548118312, 1.6324588293673465, 0.4538864113835555, 1.4357971260313207e-05, 6.908662358681066e-05, 1.300899046101371e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361208898779722
# En la iteración 4 obtenemos:
# Suma de fracciones molares: 1.0008355002286253
# Temperatura de combustión inicial: 1558.2080287395006K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.0004196596938750516, 0.49373346640716975, 0.0027659090232345436, 0.8787314641785542, 0.4014722572323276, 1.634320667112818, 0.4540050187351537, 1.429706900223128e-05, 6.886343035627432e-05, 1.296016507163221e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361887374685354
# En la iteración 5 obtenemos:
# Suma de fracciones molares: 1.0008356742863136
# Temperatura de combustión inicial: 1559.9759886984618K
# Los coeficientes:  N_KOH, N_K2CO3, N_K2O, N_CO, N_CO2, N_H2O, N_H2, N_H, N_OH, N_O, N_O2, N_N2
# [0.00041965969401099067, 0.49373346640772436, 0.0027659090234253224, 0.8787314641793276, 0.40147225723231883, 1.634320667108554, 0.45400501873601684, 1.4911150880989092e-05, 6.900857928979983e-05, 1.2959053766385876e-07, 1e-10, 0.5]
# Suma de coeficientes (N_m): 4.361887374683268
# Archivo generado exitosamente en:
#  2.17 1.0 1559.98 33.9148 21.6237 384.4928 1.3248 891.4 0.00041965969401099067 0.49373346640772436 0.0027659090234253224 0.8787314641793276 0.40147225723231883 1.634320667108554 0.45400501873601684 1.4911150880989092e-05 6.900857928979983e-05 1.2959053766385876e-07 1e-10 0.5
# Archivo generado exitosamente en: C:/Users/german.perez/OneDrive - Destinus NL BV/Escritorio/Personal/TFG/Fotos/6 - Resultados\resultados_equilibrio.txt
